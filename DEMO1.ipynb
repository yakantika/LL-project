# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
#  50%|██████████████████████▌                      | 1/2 [00:00<00:00,  3.12it/s]
# Number of chunks =  23
# of research has been conducted continuously on these solutions in recent years
#
# (Dai et al, 2020b). The proposed knowledge graphs are widely employed in
#
# various AI systems recently (Ko et al, 2021; Mohamed et al, 2021), such as rec-
#
# ommender systems, question answering, and information retrieval. They are
#
# also widely applied in many fields (e.g., education and medical care) to benefit
#
# human life and society. (Sun et al, 2020; Bounhas et al, 2020).

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (23, 3)
#                                                 text  \
# 0  1 Introduction\n\nKnowledge plays a vital role...
# 1  human knowledge according to different concept...
# 2  entities (Hogan et al, 2021; Cheng et al, 2022...
# 3  of research has been conducted continuously on...
# 4  Therefore, knowledge graphs have seized great ...
#
#                                           source  \
# 0  data_input/cureus/cureus-0015-00000040274.txt
# 1  data_input/cureus/cureus-0015-00000040274.txt
# 2  data_input/cureus/cureus-0015-00000040274.txt
# 3  data_input/cureus/cureus-0015-00000040274.txt
# 4  data_input/cureus/cureus-0015-00000040274.txt
#
#                            chunk_id
# 0  3d1c25046d0c4e73a20dcc73939628af
# 1  fa8539dd48624b88ab07b8f688cd2b72
# 2  4bd1375f70a14cab8a811946f3dba23c
# 3  e2345789c78941bb801442c491a79140
# 4  4ef57d094e9b43d4929eca2c82b45faf

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %%
# Function to process data in batches
def process_batches(dataframe, batch_size=2):
    for i in range(0, len(dataframe), batch_size):
        yield dataframe.iloc[i:i+batch_size]

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

# if regenerate:
#     concepts_list = df2Graph(df, model='mistral-openorca:latest')
#     dfg1 = graph2Df(concepts_list)
#     if not os.path.exists(outputdirectory):
#         os.makedirs(outputdirectory)
    
#     dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
#     df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
# else:
#     dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

# dfg1.replace("", np.nan, inplace=True)
# dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
# dfg1['count'] = 4 
# ## Increasing the weight of the relation to 4. 
# ## We will assign the weight of 1 when later the contextual proximity will be calculated.  
# print(dfg1.shape)
# dfg1.head()

if regenerate:
    # Assuming df and model are defined elsewhere
    chunks = process_batches(df)
    first_chunk = True
    for chunk_idx, chunk in enumerate(chunks):
        concepts_list = df2Graph(chunk, model='mistral-openorca:latest')
        dfg1 = pd.DataFrame(concepts_list)
        dfg1.replace("", np.nan, inplace=True)
        dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
        dfg1['count'] = 4 
        
        if first_chunk:
            mode = 'w'
            first_chunk = False
        else:
            mode = 'a'
        dfg1.to_csv(os.path.join(outputdirectory, "graph.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
        chunk.to_csv(os.path.join(outputdirectory, "chunks.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
else:
    dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")

dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
print(dfg1.shape)
print(dfg1.head())
# Out:
#  [
#    {
#        "node_1": "Knowledge",
#        "node_2": "Human existence and development",
#        "edge": "knowledge plays a vital role"
#    },
#    {
#        "node_1": "Learning",
#        "node_2": "Representing human knowledge",
#        "edge": "crucial tasks in artificial intelligence research"
#    },
#    {
#        "node_1": "Artificial Intelligence",
#        "node_2": "Solve complex tasks in realistic scenarios",
#        "edge": "AI systems require additional knowledge to obtain the same abilities"
#    },
#    {
#        "node_1": "Emergence of approaches",
#        "node_2": "Representing human knowledge",
#        "edge": "support these systems, we have seen"
#    }
# ] [
#     {
#         "node_1": "human knowledge",
#         "node_2": "conceptual models",
#         "edge": "according to"
#     },
#     {
#         "node_1": "knowledge graphs",
#         "node_2": "standard solution",
#         "edge": "in this space"
#     },
#     {
#         "node_1": "knowledge graphs",
#         "node_2": "research trend",
#         "edge": "in academia and industry (Kong et al, 2022)"
#     },
#     {
#         "node_1": "knowledge graphs",
#         "node_2": "graphs of data",
#         "edge": "accumulate and convey"
#     },
#     {
#         "node_1": "entities of interest",
#         "node_2": "nodes in the knowledge graphs",
#         "edge": "represent"
#     },
#     {
#         "node_1": "relations between the entities",
#         "node_2": "edges in the knowledge graphs",
#         "edge": "represent"
#     }
# ] [
#     {
#         "node_1": "entities (Hogan et al, 2021; Cheng et al, 2022b)",
#         "node_2": "formal semantics",
#         "edge": "used in"
#     },
#     {
#         "node_1": "example",
#         "node_2": "entity ‘Bill Gates’ and entity ‘Microsoft’",
#         "edge": "have relationships in the real world"
#     }
# ] [
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "AI systems",
#        "edge": "are widely employed in"
#    },
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "rec-ommender systems, question answering, and information retrieval",
#        "edge": "are widely employed in"
#    },
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "education and medical care",
#        "edge": "are also widely applied in"
#    },
#    {
#        "node_1": "proposed knowledge graphs",
#        "node_2": "Dai et al, 2020b",
#        "edge": "by"
#    },
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "Ko et al, 2021; Mohamed et al, 2021",
#        "edge": "recently"
#    }
# ] [
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "AI systems",
#        "edge": "have seized great opportunities"
#    }, {
#        "node_1": "knowledge graphs",
#        "node_2": "various areas",
#        "edge": "are applied to"
#    }, {
#        "node_1": "knowledge graphs",
#        "node_2": "technical challenges",
#        "edge": "research on knowledge graphs still faces"
#    }, {
#        "node_1": "knowledge graphs",
#        "node_2": "major limitations",
#        "edge": "in the current technologies for acquiring knowledge from multiple sources and integrating them into a typical knowledge graph"
#    }
# ] [
#    {
#        "node_1": "knowledge graph",
#        "node_2": "technical challenges",
#        "edge": "are associated with each other in the context of their development"
#    },
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "opportunities and challenges",
#        "edge": "are discussed in terms of"
#    }
# ] [
#     {
#         "node_1": "AI systems",
#         "node_2": "Knowledge Graphs",
#         "edge": "performance is significantly improved by"
#     },
#     {
#         "node_1": "knowledge graphs",
#         "node_2": "application fields that benefit from knowledge graphs",
#         "edge": "benefit from"
#     },
#     {
#         "node_1": "knowledge graph technologies",
#         "node_2": "limitations of knowledge graph technologies",
#         "edge": "considering the"
#     }
# ] [
#    {
#        "node_1": "knowledge graph studies",
#        "node_2": "advancements in knowledge graphs",
#        "edge": "relationship between the two concepts in one sentence"
#    },
#    {
#        "node_1": "knowledge graph opportunities",
#        "node_2": "knowledge graph-based AI systems",
#        "edge": "relationship between the two concepts in one sentence"
#    },
#    {
#        "node_1": "knowledge graph opportunities",
#        "node_2": "application fields that utilize knowledge graphs",
#        "edge": "relationship between the two concepts in one sentence"
#    },
#    {
#        "node_1": "benefits of knowledge graphs",
#        "node_2": "AI systems",
#        "edge": "relationship between the two concepts in one sentence"
#    },
#    {
#        "node_1": "knowledge graph opportunities",
#        "node_2": "recommender systems",
#        "edge": "relationship between the two concepts in one sentence"
#    }
# ] [
#    {
#        "node_1": "question-answering systems",
#        "node_2": "information retrieval",
#        "edge": "are mentioned in the same sentence"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "human society",
#        "edge": "are mentioned in the same sentence"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "education",
#        "edge": "are mentioned in the same context"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "scientific research",
#        "edge": "are mentioned in the same context"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "social media",
#        "edge": "are mentioned in the same context"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "medical care",
#        "edge": "are mentioned in the same context"
#    },
#    {
#        "node_1": "knowledge graph challenges",
#        "node_2": "technical challenges",
#        "edge": "are mentioned in the same sentence"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "technical challenges",
#        "edge": "are mentioned in the same context"
#    }
# ] [
#    {
#        "node_1": "knowledge graph embeddings",
#        "node_2": "knowledge graph technologies",
#        "edge": "included in"
#    },
#    {
#        "node_1": "knowledge acquisition",
#        "node_2": "knowledge graph technologies",
#        "edge": "included in"
#    },
#    {
#        "node_1": "knowledge graph completion",
#        "node_2": "knowledge graph technologies",
#        "edge": "included in"
#    },
#    {
#        "node_1": "knowledge fusion",
#        "node_2": "knowledge graph technologies",
#        "edge": "included in"
#    },
#    {
#        "node_1": "knowledge reasoning",
#        "node_2": "knowledge graph technologies",
#        "edge": "included in"
#    }
# ] [
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "data set",
#        "edge": "are"
#    },
#    {
#        "node_1": "real-world facts",
#        "node_2": "knowledge graphs",
#        "edge": "represent"
#    }
# ] [
#    {
#        "node_1": "semantic relations in the form of triplets",
#        "node_2": "knowledge graph",
#        "edge": "representation as"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "ontology",
#        "edge": "schema for"
#    }
# ] [
#    {
#        "node_1": "knowledge graph construction",
#        "node_2": "ontology construction",
#        "edge": "is"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "opportunities and challenges",
#        "edge": "topics in"
#    },
#    {
#        "node_1": "Knowledge Graphs",
#        "node_2": "Opportunities and Challenges",
#        "edge": "book chapters in"
#    },
#    {
#        "node_1": "example of a knowledge graph",
#        "node_2": "triplet",
#        "edge": "representation of"
#    },
#    {
#        "node_1": "(e1 , r1 , e2 )",
#        "node_2": "triplet",
#        "edge": "is a form of"
#    },
#    {
#        "node_1": "knowledge graph construction",
#        "node_2": "Google Knowledge Graph",
#        "edge": "example of"
#    },
#    {
#        "node_1": "Ehrlinger and Wöß, 2016",
#        "node_2": "introduced",
#        "edge": "by"
#    },
#    {
#        "node_1": "knowledge graph construction",
#        "node_2": "ontology construction",
#        "edge": "has a relation with"
#    }
# ] [
#    {
#        "node_1": "DBpedia",
#        "node_2": "knowledge graph",
#        "edge": "is a"
#    },
#    {
#        "node_1": "DBpedia",
#        "node_2": "Wikipedia",
#        "edge": "extracts information from"
#    },
#    {
#        "node_1": "DBpedia",
#        "node_2": "well-structured ontological knowledge base",
#        "edge": "converts it into an effective"
#    },
#    {
#        "node_1": "Auer et al",
#        "node_2": "2007",
#        "edge": "refers to"
#    },
#    {
#        "node_1": "Freebase",
#        "node_2": "knowledge graph",
#        "edge": "is a"
#    },
#    {
#        "node_1": "Freebase",
#        "node_2": "multiple sources",
#        "edge": "provides information from"
#    },
#    {
#        "node_1": "Bollacker et al",
#        "node_2": "2008",
#        "edge": "refers to"
#    },
#    {
#        "node_1": "Facebook's entity graph",
#        "node_2": "knowledge graph",
#        "edge": "is a"
#    },
#    {
#        "node_1": "Facebook's entity graph",
#        "node_2": "unstructured",
#        "edge": "converts the"
#    }
# ] [
#    {
#        "node_1": "structured data",
#        "node_2": "user profiles",
#        "edge": "content of the user profiles is transformed into structured data"
#    },
#    {
#        "node_1": "Wikidata",
#        "node_2": "knowledge graph",
#        "edge": "Wikidata is a cross-lingual document-oriented knowledge graph"
#    },
#    {
#        "node_1": "Wikipedia",
#        "node_2": "supports sites and services",
#        "edge": "Wikipedia is supported by many sites and services"
#    },
#    {
#        "node_1": "Vrandečić and Krötzsch, 2014",
#        "node_2": "Wikidata",
#        "edge": "Vrandečić and Krötzsch, 2014 is related to Wikidata"
#    },
#    {
#        "node_1": "Yago",
#        "node_2": "knowledge base",
#        "edge": "Yago is a knowledge base"
#    },
#    {
#        "node_1": "Rebele et al, 2016",
#        "node_2": "Yago",
#        "edge": "Rebele et al, 2016 is related to Yago"
#    },
#    {
#        "node_1": "Wikipedia",
#        "node_2": "source of entities and relationships",
#        "edge": "Entities are extracted from Wikipedia"
#    },
#    {
#        "node_1": "WordNet",
#        "node_2": "source of entities and relationships",
#        "edge": "Entities are extracted from WordNet"
#    }
#  ] [
#    {
#        "node_1": "WordNet",
#        "node_2": "lexical knowledge base",
#        "edge": "is a"
#    },
#    {
#        "node_1": "WordNet",
#        "node_2": "measure the semantic similarity between words",
#        "edge": "to"
#    },
#    {
#        "node_1": "knowledge base",
#        "node_2": "contains a number of hierarchical concept graphs",
#        "edge": "contain"
#    },
#    {
#        "node_1": "knowledge base",
#        "node_2": "analyse the semantic similarity",
#        "edge": "to analyse"
#    },
#    {
#        "node_1": "hierarchical concept graphs",
#        "node_2": "semantic similarity (Pedersen et al, 2004)",
#        "edge": "for"
#    },
#    {
#        "node_1": "knowledge graph",
#        "node_2": "directed graph composed of nodes and edges",
#        "edge": "composed of"
#    },
#    {
#        "node_1": "entity",
#        "node_2": "real object or abstract concept",
#        "edge": "indicates an"
#    },
#    {
#        "node_1": "edge",
#        "node_2": "semantic relation between the two entities",
#        "edge": "conveys the"
#    }
# ] [
#    {
#        "node_1": "ties",
#        "node_2": "Bordes et al, 2011",
#        "edge": "author of"
#    }, {
#        "node_1": "Resource Description Framework (RDF)",
#        "node_2": "knowledge graph",
#        "edge": "typical way to represent and manage"
#    }, {
#        "node_1": "Labeled Property Graphs (LPGs)",
#        "node_2": "knowledge graph",
#        "edge": "another typical way to represent and manage"
#    }, {
#        "node_1": "fundamental unit",
#        "node_2": "knowledge graph",
#        "edge": "represents in"
#    }, {
#        "node_1": "triple (subject, predicate, object)",
#        "node_2": "knowledge graph",
#        "edge": "used as a basic structure of"
#    }, {
#        "node_1": "(Bill Gates, founderOf, Microsoft)",
#        "node_2": "knowledge graph",
#        "edge": "example of triple in"
#    }
# ] [
#    {
#        "node_1": "knowledge graph",
#        "node_2": "directed graph",
#        "edge": "is a"
#    }, {
#        "node_1": "Knowledge Graphs: Opportunities and Challenges",
#        "node_2": "context",
#        "edge": "mentioned in the same sentence as"
#    }, {
#        "node_1": "example of a simple knowledge graph",
#        "node_2": "Fig. 1",
#        "edge": "shown in"
#    }, {
#        "node_1": "nodes e1 and e2 darkened in color",
#        "node_2": "example of a simple knowledge graph",
#        "edge": "part of"
#    }, {
#        "node_1": "relation r1",
#        "node_2": "nodes e1 and e2",
#        "edge": "connects"
#    }, {
#        "node_1": "(e1 , r1 , e2 )",
#        "node_2": "triplet",
#        "edge": "formed by"
#    }
# ] [
#    {
#        "node_1": "knowledge graphs",
#        "node_2": "current research on knowledge graphs",
#        "edge": "which e1 and e2 are the head and tail entities, respectively."
#    },
#    {
#        "node_1": "Plenty of studies",
#        "node_2": "focused on exploring knowledge graphs",
#        "edge": "In recent years, knowledge graphs have gained extensive research interest."
#    },
#    {
#        "node_1": "Paper",
#        "node_2": "Conducts a comprehensive survey on knowledge graphs",
#        "edge": "This paper conducts a comprehensive survey on knowledge graphs and lists seven important categories of current research on this topic."
#    },
#    {
#        "node_1": "Important categories",
#        "node_2": "Current research on knowledge graphs",
#        "edge": "lists seven important categories of current research on this topic."
#    },
#    {
#        "node_1": "Schema",
#        "node_2": "Most popular research lines regarding knowledge graphs",
#        "edge": "Fig. 2 illustrates a schema of the most popular research lines regarding knowledge graphs."
#    }
# ] [
#    {
#        "node_1": "AI systems",
#        "node_2": "services",
#        "edge": "utilize"
#    }, {
#        "node_1": "knowledge graph for foundation",
#        "node_2": "application fields",
#        "edge": "reach in"
#    }, {
#        "node_1": "research lines",
#        "node_2": "discussing opportunities",
#        "edge": "for knowledge graphs"
#    }, {
#        "node_1": "five research lines",
#        "node_2": "knowledge graph technologies",
#        "edge": "corresponding to five tasks"
#    }, {
#        "node_1": "introduce",
#        "node_2": "five main knowledge graph technologies",
#        "edge": "in this paper"
#    }
# ] [
#    {
#        "node_1": "Knowledge Graph Embedding",
#        "node_2": "research issue",
#        "edge": "central to the research issue"
#    },
#    {
#        "node_1": "Knowledge graph embedding",
#        "node_2": "mapping entities and relations",
#        "edge": "maps entities and relations of a knowledge graph"
#    },
#    {
#        "node_1": "Knowledge graph embedding",
#        "node_2": "low-dimensional vector space",
#        "edge": "maps to a low-dimensional vector space"
#    },
#    {
#        "node_1": "knowledge graph embedding",
#        "node_2": "semantics and structure of knowledge graph",
#        "edge": "captures the semantics and structure of the knowledge graph"
#    },
#    {
#        "node_1": "obtained feature vector",
#        "node_2": "machine learning models",
#        "edge": "effectively learned by machine learning models"
#    }
# ] [
#    {
#        "node_1": "tensor factorization-based",
#        "node_2": "translation-based",
#        "edge": "methods for"
#    }, {
#        "node_1": "tensor factorization-based",
#        "node_2": "neural network-based methods",
#        "edge": "methods for"
#    }, {
#        "node_1": "knowledge graph study",
#        "node_2": "knowledge acquisition",
#        "edge": "another crucial research direction of"
#    }, {
#        "node_1": "structured sources",
#        "node_2": "knowledge graphs",
#        "edge": "importing from"
#    }, {
#        "node_1": "mapping languages",
#        "node_2": "R2RML",
#        "edge": "such as"
#    }
# ] [
#    {
#        "node_1": "Knowledge Graphs",
#        "node_2": "Opportunities and Challenges",
#        "edge": "are related in the title of the document"
#    }, {
#        "node_1": "unstructured documents",
#        "node_2": "news, research papers, and patents",
#        "edge": "are mentioned in the same sentence"
#    }, {
#        "node_1": "relation, entity, or attribute extraction methods",
#        "node_2": "(Liu et al, 2020; Yu et al, 2020; Yao et al, 2019)",
#        "edge": "are mentioned in the same sentence"
#    }
# ]

# %%
# dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
# dfg1.replace("", np.nan, inplace=True)
# dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
# dfg1['count'] = 4 
# print(dfg1.shape)
# print(dfg1.head())
# Out:
# (116, 5)
#                     node_1                                      node_2  \
# 0                Knowledge             Human existence and development
# 1                 Learning                Representing human knowledge
# 2  Artificial Intelligence  Solve complex tasks in realistic scenarios
# 3  Emergence of approaches                Representing human knowledge
# 4          human knowledge                           conceptual models
#
#                                                 edge  \
# 0                       knowledge plays a vital role
# 1  crucial tasks in artificial intelligence research
# 2  AI systems require additional knowledge to obt...
# 3                support these systems, we have seen
# 4                                       according to
#
#                            chunk_id  count
# 0  3d1c25046d0c4e73a20dcc73939628af      4
# 1  3d1c25046d0c4e73a20dcc73939628af      4
# 2  3d1c25046d0c4e73a20dcc73939628af      4
# 3  3d1c25046d0c4e73a20dcc73939628af      4
# 4  fa8539dd48624b88ab07b8f688cd2b72      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                                           node_1                   node_2  \
# 1492                               various areas         knowledge graphs
# 1499  well-structured ontological knowledge base                  DBpedia
# 1500  well-structured ontological knowledge base  Facebook's entity graph
# 1501  well-structured ontological knowledge base                 Freebase
# 1503  well-structured ontological knowledge base          knowledge graph
#
#                                                chunk_id  count  \
# 1492  4ef57d094e9b43d4929eca2c82b45faf,4ef57d094e9b4...      4
# 1499  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...      3
# 1500  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...      2
# 1501  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...      2
# 1503  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...      3
#
#                       edge
# 1492  contextual proximity
# 1499  contextual proximity
# 1500  contextual proximity
# 1501  contextual proximity
# 1503  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                          node_1  \
# 0            (Bill Gates, founderOf, Microsoft)
# 1                               (e1 , r1 , e2 )
# 2                               (e1 , r1 , e2 )
# 3                               (e1 , r1 , e2 )
# 4                               (e1 , r1 , e2 )
# ..                                          ...
# 488                               various areas
# 489  well-structured ontological knowledge base
# 490  well-structured ontological knowledge base
# 491  well-structured ontological knowledge base
# 492  well-structured ontological knowledge base
#
#                                   node_2  \
# 0                        knowledge graph
# 1    example of a simple knowledge graph
# 2                        knowledge graph
# 3           knowledge graph construction
# 4                  ontology construction
# ..                                   ...
# 488                     knowledge graphs
# 489                              DBpedia
# 490              Facebook's entity graph
# 491                             Freebase
# 492                      knowledge graph
#
#                                               chunk_id  \
# 0    f035c1db86364da28114308ab5ba634b,f035c1db86364...
# 1    5e217a142f9f4085bc72161560094a99,5e217a142f9f4...
# 2    b564f4818b6a40e881a17664f76e6969,5e217a142f9f4...
# 3    b564f4818b6a40e881a17664f76e6969,b564f4818b6a4...
# 4    b564f4818b6a40e881a17664f76e6969,b564f4818b6a4...
# ..                                                 ...
# 488  4ef57d094e9b43d4929eca2c82b45faf,4ef57d094e9b4...
# 489  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...
# 490  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...
# 491  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...
# 492  de50b40ec9594391a1b6740daf2aad3b,de50b40ec9594...
#
#                                           edge  count
# 0    example of triple in,contextual proximity      9
# 1                         contextual proximity      2
# 2                         contextual proximity      2
# 3                         contextual proximity      3
# 4                         contextual proximity      2
# ..                                         ...    ...
# 488                       contextual proximity      4
# 489                       contextual proximity      3
# 490                       contextual proximity      2
# 491                       contextual proximity      2
# 492                       contextual proximity      3
#
# [493 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (153,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  16
# [['(Bill Gates, founderOf, Microsoft)', '(e1 , r1 , e2 )', '2007', '2008', 'Auer et al', 'Bollacker et al', 'Bordes et al, 2011', 'DBpedia', 'Ehrlinger and Wöß, 2016', "Facebook's entity graph", 'Fig. 1', 'Freebase', 'Google Knowledge Graph', 'Knowledge Graphs', 'Knowledge Graphs: Opportunities and Challenges', 'Labeled Property Graphs (LPGs)', 'Opportunities and Challenges', 'Rebele et al, 2016', 'Resource Description Framework (RDF)', 'Vrandečić and Krötzsch, 2014', 'Wikidata', 'Wikipedia', 'WordNet', 'Yago', 'analyse the semantic similarity', 'contains a number of hierarchical concept graphs', 'context', 'directed graph', 'directed graph composed of nodes and edges', 'edge', 'education', 'entity', 'example of a knowledge graph', 'example of a simple knowledge graph', 'fundamental unit', 'hierarchical concept graphs', 'human society', 'information retrieval', 'introduced', 'knowledge base', 'knowledge graph', 'knowledge graph challenges', 'knowledge graph construction', 'lexical knowledge base', 'measure the semantic similarity between words', 'medical care', 'multiple sources', 'nodes e1 and e2', 'nodes e1 and e2 darkened in color', 'ontology', 'ontology construction', 'opportunities and challenges', 'question-answering systems', 'real object or abstract concept', 'relation r1', 'scientific research', 'semantic relation between the two entities', 'semantic relations in the form of triplets', 'semantic similarity (Pedersen et al, 2004)', 'social media', 'source of entities and relationships', 'structured data', 'supports sites and services', 'technical challenges', 'ties', 'triple (subject, predicate, object)', 'triplet', 'unstructured', 'user profiles', 'well-structured ontological knowledge base'], ['(Liu et al, 2020; Yu et al, 2020; Yao et al, 2019)', 'relation, entity, or attribute extraction methods'], ['AI systems', 'R2RML', 'advancements in knowledge graphs', 'application fields that utilize knowledge graphs', 'benefits of knowledge graphs', 'five research lines', 'knowledge acquisition', 'knowledge fusion', 'knowledge graph completion', 'knowledge graph embeddings', 'knowledge graph opportunities', 'knowledge graph studies', 'knowledge graph study', 'knowledge graph technologies', 'knowledge graph-based AI systems', 'knowledge reasoning', 'limitations of knowledge graph technologies', 'mapping languages', 'neural network-based methods', 'recommender systems', 'services', 'tensor factorization-based', 'translation-based'], ['Artificial Intelligence', 'Emergence of approaches', 'Human existence and development', 'Knowledge', 'Learning', 'Representing human knowledge', 'Solve complex tasks in realistic scenarios'], ['Conducts a comprehensive survey on knowledge graphs', 'Paper'], ['Current research on knowledge graphs', 'Important categories'], ['Dai et al, 2020b', 'Ko et al, 2021; Mohamed et al, 2021', 'application fields that benefit from knowledge graphs', 'conceptual models', 'current research on knowledge graphs', 'data set', 'edges in the knowledge graphs', 'education and medical care', 'entities of interest', 'graphs of data', 'human knowledge', 'knowledge graphs', 'major limitations', 'nodes in the knowledge graphs', 'proposed knowledge graphs', 'real-world facts', 'rec-ommender systems, question answering, and information retrieval', 'relations between the entities', 'research trend', 'standard solution', 'structured sources', 'various areas'], ['Knowledge Graph Embedding', 'Knowledge graph embedding', 'knowledge graph embedding', 'low-dimensional vector space', 'machine learning models', 'mapping entities and relations', 'obtained feature vector', 'research issue', 'semantics and structure of knowledge graph'], ['Most popular research lines regarding knowledge graphs', 'Schema'], ['Plenty of studies', 'focused on exploring knowledge graphs'], ['application fields', 'knowledge graph for foundation'], ['discussing opportunities', 'research lines'], ['entities (Hogan et al, 2021; Cheng et al, 2022b)', 'formal sem ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                        node    color  group
# 0        (Bill Gates, founderOf, Microsoft)  #57db80      1
# 1                           (e1 , r1 , e2 )  #57db80      1
# 2                                      2007  #57db80      1
# 3                                      2008  #57db80      1
# 4                                Auer et al  #57db80      1
# ..                                      ...      ...    ...
# 148                                 example  #57a2db     14
# 149  five main knowledge graph technologies  #db5780     15
# 150                               introduce  #db5780     15
# 151      news, research papers, and patents  #57dbb2     16
# 152                  unstructured documents  #57dbb2     16
#
# [153 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
