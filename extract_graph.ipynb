# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
# loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
#  50%|██████████████████████▌                      | 1/2 [01:37<01:37, 97.80s/it]
# Number of chunks =  135916
# The authors declare no conflict of interest.
#
# 4 8 2022 9 2022 4 8 2022 11 9 e00181-2221 3 2022 19 7 2022 Copyright © 2022 Palmieri et al. 2022 Palmieri et al. https://creativecommons.org/licenses/by/4.0/ This is an open-access article distributed under the terms of the Creative Commons Attribution 4.0 International license.
#
# ABSTRACT

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (135916, 3)
#                                                 text  \
# 0  # File: PMC9476978.txt\n\n==== Front Microbiol...
# 1  35924938 00181-22 10.1128/mra.00181-22 mra.001...
# 2  Udriet Pauline a https://orcid.org/0000-0002-3...
# 3  The authors declare no conflict of interest.\n...
# 4  ABSTRACT\n\nHere, we report the complete genom...
#
#                              source                          chunk_id
# 0  data_input/cureus/op1000file.txt  e291fbfbdf6a482391de9bc015c8e89b
# 1  data_input/cureus/op1000file.txt  f582a51c2c1b4ddc88eea1014faba83e
# 2  data_input/cureus/op1000file.txt  d3736d3c22874f41bfe914c4b02616f1
# 3  data_input/cureus/op1000file.txt  e60d2deaaf254247b115b7dffbea2bd9
# 4  data_input/cureus/op1000file.txt  52c4f6c785764df684cf85439640d1c4

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %%
# Function to process data in batches
def process_batches(dataframe, batch_size=2):
    for i in range(0, len(dataframe), batch_size):
        yield dataframe.iloc[i:i+batch_size]

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = False

# if regenerate:
#     concepts_list = df2Graph(df, model='mistral-openorca:latest')
#     dfg1 = graph2Df(concepts_list)
#     if not os.path.exists(outputdirectory):
#         os.makedirs(outputdirectory)
    
#     dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
#     df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
# else:
#     dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

# dfg1.replace("", np.nan, inplace=True)
# dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
# dfg1['count'] = 4 
# ## Increasing the weight of the relation to 4. 
# ## We will assign the weight of 1 when later the contextual proximity will be calculated.  
# print(dfg1.shape)
# dfg1.head()

if regenerate:
    # Assuming df and model are defined elsewhere
    chunks = process_batches(df)
    first_chunk = True
    for chunk_idx, chunk in enumerate(chunks):
        concepts_list = df2Graph(chunk, model='mistral-openorca:latest')
        dfg1 = pd.DataFrame(concepts_list)
        dfg1.replace("", np.nan, inplace=True)
        dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
        dfg1['count'] = 4 
        
        if first_chunk:
            mode = 'w'
            first_chunk = False
        else:
            mode = 'a'
        dfg1.to_csv(os.path.join(outputdirectory, "graph.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
        chunk.to_csv(os.path.join(outputdirectory, "chunks.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
else:
    dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")

dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
print(dfg1.shape)
print(dfg1.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 42
#      40         chunk.to_csv(os.path.join(outputdirectory, "chunks.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
#      41 else:
# ---> 42     dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
#      44 dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
#      45 dfg1.replace("", np.nan, inplace=True)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 5 fields in line 1765, saw 6

# %%
dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
print(dfg1.shape)
print(dfg1.head())
# Out:
# (3374, 5)
#                          node_1  \
# 0  Cardiovascular disease (CVD)
# 1                         women
# 2                         women
# 3                         women
# 4                         women
#
#                                               node_2  \
# 0                         leading cause of mortality
# 1                                                men
# 2                      coronary artery disease (CAD)
# 3  1-year mortality rate after acute myocardial i...
# 4                                        black women
#
#                                                 edge  \
# 0                      in women in the United States
# 1                   comparison between men and women
# 2  having less obstructive but more diffuse coron...
# 3  higher 1-year mortality rate after acute myoca...
# 4                 having the highest CAD death rates
#
#                            chunk_id  count
# 0  3dc851440134402d87573a15088a4351      4
# 1  51dc59c88fb141e1a0ad643fd6109a21      4
# 2  51dc59c88fb141e1a0ad643fd6109a21      4
# 3  51dc59c88fb141e1a0ad643fd6109a21      4
# 4  51dc59c88fb141e1a0ad643fd6109a21      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#                       node_1           node_2  \
# 51029  zebrafish and in mice            SIRT1
# 51038             β blockers             ARBs
# 51054          € 192 billion              CVD
# 51069                 ≥ 7.5%  elevated hs-CRP
# 51081           ≥140 and ≥90               AH
#
#                                                 chunk_id  count  \
# 51029  9508450fd46943c092632c7e026877c4,9508450fd4694...      4
# 51038  a3cb4cf2955a46e6a1149c6b9c9a8c15,a3cb4cf2955a4...      2
# 51054  5858afe30c1d44558b8f8632fc6ad382,5858afe30c1d4...      6
# 51069  426fe5b8c62e4adfa880f23ac1d76acc,426fe5b8c62e4...      2
# 51081  c20c2bbc85ba423ebb0a4c64cf758931,c20c2bbc85ba4...      2
#
#                        edge
# 51029  contextual proximity
# 51038  contextual proximity
# 51054  contextual proximity
# 51069  contextual proximity
# 51081  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                                                   node_1  \
# 0       marine n-3 fatty acids, fish intake, and the ...
# 1                                            (1·69–2·63)
# 2                                            (1·69–2·63)
# 3                                               (95% CI)
# 4                                               (95% CI)
# ...                                                  ...
# 12865                              zebrafish and in mice
# 12866                                         β blockers
# 12867                                      € 192 billion
# 12868                                             ≥ 7.5%
# 12869                                       ≥140 and ≥90
#
#                          node_2  \
# 0      Physicians’ Health Study
# 1                          2·11
# 2                  Hazard ratio
# 3             Author Manuscript
# 4               effect estimate
# ...                         ...
# 12865                     SIRT1
# 12866                      ARBs
# 12867                       CVD
# 12868           elevated hs-CRP
# 12869                        AH
#
#                                                 chunk_id  \
# 0      c1322d3da33247ada5e8fc7a1034048b,c1322d3da3324...
# 1      fcfdafc6471042d08b1fe8b96a7be029,fcfdafc647104...
# 2      fcfdafc6471042d08b1fe8b96a7be029,fcfdafc647104...
# 3      61c8344660df49bdb13316c58314cd72,61c8344660df4...
# 4      61c8344660df49bdb13316c58314cd72,61c8344660df4...
# ...                                                  ...
# 12865  9508450fd46943c092632c7e026877c4,9508450fd4694...
# 12866  a3cb4cf2955a46e6a1149c6b9c9a8c15,a3cb4cf2955a4...
# 12867  5858afe30c1d44558b8f8632fc6ad382,5858afe30c1d4...
# 12868  426fe5b8c62e4adfa880f23ac1d76acc,426fe5b8c62e4...
# 12869  c20c2bbc85ba423ebb0a4c64cf758931,c20c2bbc85ba4...
#
#                                                     edge  count
# 0                                   contextual proximity      3
# 1                                   contextual proximity      2
# 2                                   contextual proximity      2
# 3                                   contextual proximity      2
# 4                                   contextual proximity      2
# ...                                                  ...    ...
# 12865  observed to regulate blood vessel growth in,co...      8
# 12866                               contextual proximity      2
# 12867                               contextual proximity      6
# 12868                               contextual proximity      2
# 12869                               contextual proximity      2
#
# [12870 rows x 5 columns]

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (4591,)

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  686
# [[' Omega-3 fatty acids in high-risk cardiovascular patients: a meta-analysis of randomized controlled trials. BMC Cardiovasc Disord. 2010; 10(24)', 'Filion K, El Khoury F, Bielinski M, Schiller I, Dendukuri N, Brophy JM'], [' marine n-3 fatty acids, fish intake, and the risk of coronary disease among men.', '(1·69–2·63)', '(95% CI)', '1-year mortality rate after acute myocardial infarction', '1. A varied well-balanced diet', '1.28 (1.15–1.43)', '1.41 (1.26–1.55)', '10% or greater 10-year CVD risk', '10-year ASCVD risk ≥ 7.5%', '10-year and lifetime atherosclerotic cardiovascular disease event risk', '10-year risk for heart disease and stroke assessment', '10-year risk of fatal cardiovascular disease (CVD)', '10479204', '110', '110(8): 1097–1108', '120-129 and <80', '130-139 or 80-89 AH', '1302-31', '133(13)', '138: 1100–12', '13: e0206548', '144 336 43 407 3035 50 (11)', '152: 1490-500.', '153 REVIEW ARTICLE', '15333163', '15495044', '155', '1573-403X/18 $58.00+.00', '15: 359–60', '165', '17135583', '173 (163, 183)', '18160071', '19221219', '1986', '199 (188, 209)', '1993; 88(2):523–33', '1994', '1995; 142(2): 166–75.', '1996–2011†', '1997; 95(11):2591–3', '1st degree AH', '1·14 (1·04–1·25)', '1·17', '1·86 (1·39–2·50)', '2000-2002 early cART era', '2003', '2003-2005 intermediate cART era', '2003; 47:214–20', '2004-2009 10 760 18 (HIV)', '2004; 1:CD003041', '2006-2009 late cART era', '2008; 18(4):283–90', '2009 South African study', '2010', '2010 South African guidelines', '2010-2015 10 760 34 (HIV)', '2010; 104(1):125–34', '2011 effectiveness-based guidelines', '2011 update', '2013 ACC/AHA Guidelines', '2013 ACC/AHA guideline on the assessment of cardiovascular risk', '2013 ACC/AHA lipid guidelines', '2014; 33: 924–30', '2016 European Guidelines on cardiovascular disease pre-vention in clinical practice', '2016 Mar', '2016 Mar 29', '2016; 117: 214–20', '2017', '2017 ACC/AHA/ AAPA/ABC/ACPM/AGS/AphA/ASH/ASPC/NMA guideline for the prevention, detection, evaluation, and management of high blood pressure in adults', '2017 American Heart Association (AHA) Guidelines', '2017; 216: 545–53', '2018', '2018, 14, 153-163', '2018, Vol. 14, No. 3', '20208999', '2030', '222 (211, 233)', '24 768', '24929646', '279 (265, 293)', '27: 1828–36', '2803', '287-92', '28886620', '28931222', '29273597', '29952786', '2nd degree AH', '2·11', '3 weeks', '3. Effects in patients at different levels of cardiovascular risk', '30 Median', '30 minutes to 60 minutes physical activity per day', '31·3% per 100 000 person-years', '32 (suppl 1): S5–20', '32 (suppl 1): S93–S105', '32(10):1235–43', '332(15): 977–82.', '360: 7-22', '37.9 million people living with HIV worldwide', '3776973', '39: 763–816', '4 clinical studies', '4-times increased risk', '47', '49: 228-31', '5% reduction in LDL levels', '5% to 7.5% 10-year ASCVD risk', '50,000 patients', '534,906 individuals', '55(8):636–42', '62% do not use it, rely on a subjective assessment', '7', '70-189 mg/dL', '76 835 participants', '78%', '9 cohorts', '90-92', '910 49 participants', '95% CI', '9·4% rate of sudden cardiac death', '< 25 kg/m', '< 35 inches', '<120 and <80', 'A concept from extracted ontology', 'A healthy diet', 'ACC', 'ACE inhibitors', 'ACE inhibitors, ARBs, β blockers, or mineralocorticoid antagonists', 'AFCAPS/TexCAPS', 'AFCAPS/TexCAPS Research Group', 'AH', 'AH stage 1', 'AH stage 2', 'AHA', 'AHA guidelines', 'AHA/ACC', 'AHA/ACC/HRS guideline', 'AIDS', 'AIDS 2018', 'AIDS 2018; 32 (suppl 1): S93–S105', 'AIDS 2019; 33: 2025–33', 'AIDS Patient Care STDS 2016', 'AMI events', 'ARBs', 'ART', 'ART era', 'ART initiation', 'ART side-effects', 'ART-related mechanisms', 'ART.35,62,77', 'ART.79', 'ASCVD risk factors', 'ASCVD risk score', 'AbdelRazek MA, Gutierrez J, Mampre D, et al.', 'Aboyans V, Ricco JB, Bartelink MEL, et al.', 'Acta Med Croatica 2007; 61(3)', 'Active HIV replication', 'Additional testing (eg, ankle-brachial index)', 'Adjudicated heart failure in HIV-infected and uninfected men and women ...

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                                                    node    color  group
# 0      Omega-3 fatty acids in high-risk cardiovascul...  #57db94      1
# 1     Filion K, El Khoury F, Bielinski M, Schiller I...  #57db94      1
# 2      marine n-3 fatty acids, fish intake, and the ...  #8d57db      2
# 3                                           (1·69–2·63)  #8d57db      2
# 4                                              (95% CI)  #8d57db      2
# ...                                                 ...      ...    ...
# 4586                       using HIV-population cohorts  #db577c    684
# 4587                                        to stimulus  #d5db57    685
# 4588                  variable cardiovascular responses  #d5db57    685
# 4589                             untreated HIV patients  #57db61    686
# 4590                                      vascular unit  #57db61    686
#
# [4591 rows x 3 columns]

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
# Out:
# ./docs/index.html
