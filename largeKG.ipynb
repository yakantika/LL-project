# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import os
from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# ## Load Documents

# %%
## Dir PDF Loader
loader = PyPDFDirectoryLoader(inputdirectory)
## File Loader
# loader = PyPDFLoader("./data/MedicalDocuments/orf-path_health-n1.pdf")
# loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    length_function=len,
    is_separator_regex=False,
)

pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))
print(pages[3].page_content)
# Out:
# Ignoring wrong pointing object 56 0 (offset 0)
# Ignoring wrong pointing object 59 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Number of chunks =  770
# risk factors for CVD and the current state of prevention, guidelines, and management of CVD in women.TRADITIONAL RISK FACTORS
# Non-Modifiable
# Age.  Age is one of the most powerful risk factors for developing
# CVD. The cardioprotective effect of estrogen for premenopausal
# women results in a roughly 8- to 10-year lag in the onset of CAD in women. After the age of 55, the risk for CAD increases similarly in both men and women.
# 7
# Modifiable
# Smoking.  According to the American Heart Association

# %% [markdown]
# ## Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (770, 4)
#                                                 text  \
# 0  REVIEW METHODIST DEBAKEY CARDIOVASC J | 13 (4)...
# 1  between men and women are summarized in Table ...
# 2  therefore, should begin with awareness of the ...
# 3  risk factors for CVD and the current state of ...
# 4  (AHA), 13% of women in the United States who a...
#
#                                       source  page  \
# 0  data_input/cureus/i1947-6094-13-4-185.pdf     0
# 1  data_input/cureus/i1947-6094-13-4-185.pdf     0
# 2  data_input/cureus/i1947-6094-13-4-185.pdf     0
# 3  data_input/cureus/i1947-6094-13-4-185.pdf     0
# 4  data_input/cureus/i1947-6094-13-4-185.pdf     0
#
#                            chunk_id
# 0  3dc851440134402d87573a15088a4351
# 1  51dc59c88fb141e1a0ad643fd6109a21
# 2  5e5c6f31324f4f8ea805b0964a33cf41
# 3  08615e84dd1245e2b5c0037f8325f1c0
# 4  bee9f43fb9a2448195d98d5d70438e54

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %%
# Function to process data in batches
def process_batches(dataframe, batch_size=2):
    for i in range(0, len(dataframe), batch_size):
        yield dataframe.iloc[i:i+batch_size]

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
regenerate = True

# if regenerate:
#     concepts_list = df2Graph(df, model='mistral-openorca:latest')
#     dfg1 = graph2Df(concepts_list)
#     if not os.path.exists(outputdirectory):
#         os.makedirs(outputdirectory)
    
#     dfg1.to_csv(outputdirectory/"graph.csv", sep="|", index=False)
#     df.to_csv(outputdirectory/"chunks.csv", sep="|", index=False)
# else:
#     dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")

# dfg1.replace("", np.nan, inplace=True)
# dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
# dfg1['count'] = 4 
# ## Increasing the weight of the relation to 4. 
# ## We will assign the weight of 1 when later the contextual proximity will be calculated.  
# print(dfg1.shape)
# dfg1.head()

if regenerate:
    # Assuming df and model are defined elsewhere
    chunks = process_batches(df)
    first_chunk = True
    for chunk_idx, chunk in enumerate(chunks):
        concepts_list = df2Graph(chunk, model='mistral-openorca:latest')
        dfg1 = pd.DataFrame(concepts_list)
        dfg1.replace("", np.nan, inplace=True)
        dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
        dfg1['count'] = 4 
        
        if first_chunk:
            mode = 'w'
            first_chunk = False
        else:
            mode = 'a'
        dfg1.to_csv(os.path.join(outputdirectory, "graph.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
        chunk.to_csv(os.path.join(outputdirectory, "chunks.csv"), sep="|", mode=mode, index=False, header=not bool(chunk_idx))
else:
    dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")

dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
print(dfg1.shape)
print(dfg1.head())
# Out:
#  [
#    {
#        "node_1": "Cardiovascular disease (CVD)",
#        "node_2": "leading cause of mortality",
#        "edge": "in women in the United States"
#    }, {
#        "node_1": "Overall management of CVD",
#        "node_2": "similar for both genders",
#        "edge": ""
#    }, {
#        "node_1": "Gender-based variations",
#        "node_2": "exist in pathophysiology",
#        "edge": ""
#    }, {
#        "node_1": "Gender-based variations",
#        "node_2": "exist in symptoms",
#        "edge": ""
#    }, {
#        "node_1": "Gender-based variations",
#        "node_2": "exist in presentation",
#        "edge": ""
#    }, {
#        "node_1": "Gender-based variations",
#        "node_2": "exist in efficacy of diagnostic tests",
#        "edge": ""
#    }, {
#        "node_1": "Gender-based variations",
#        "node_2": "exist in response to pharmacological interventions",
#        "edge": ""
#    }
# ] [
#    {
#        "node_1": "women",
#        "node_2": "men",
#        "edge": "comparison between men and women"
#    }, {
#        "node_1": "women",
#        "node_2": "coronary artery disease (CAD)",
#        "edge": "having less obstructive but more diffuse coronary artery disease (CAD)"
#    }, {
#        "node_1": "women",
#        "node_2": "1-year mortality rate after acute myocardial infarction",
#        "edge": "higher 1-year mortality rate after acute myocardial infarction"
#    }, {
#        "node_1": "women",
#        "node_2": "black women",
#        "edge": "having the highest CAD death rates"
#    }, {
#        "node_1": "women",
#        "node_2": "physicians",
#        "edge": "less aware of and less proficient in identifying CVD in women"
#    }, {
#        "node_1": "prevention and management of CVD in women",
#        "node_2": "women",
#        "edge": "related to prevention and management of CVD in women"
#    }
# ] [
#    {
#        "node_1": "CVD prevention",
#        "node_2": "guidelines for women",
#        "edge": "were published in 2004 and later updated in 2007 and 2011"
#    }, {
#        "node_1": "CVD prevention",
#        "node_2": "general CVD risk factors",
#        "edge": "are similar in men and women"
#    }, {
#        "node_1": "CVD prevention",
#        "node_2": "exceptions unique to women",
#        "edge": "were detailed in these guidelines"
#    }
# ] [
#     {
#         "node_1": "CVD",
#         "node_2": "risk factors for CVD",
#         "edge": "topic being discussed"
#     },
#     {
#         "node_1": "Non-Modifiable",
#         "node_2": "Age",
#         "edge": "one of the non-modifiable risk factors"
#     },
#     {
#         "node_1": "Age",
#         "node_2": "developing CVD",
#         "edge": "relationship between age and developing CVD"
#     },
#     {
#         "node_1": "Cardioprotective effect",
#         "node_2": "estrogen for premenopausal women",
#         "edge": "cardioprotective effect of estrogen on premenopausal women"
#     },
#     {
#         "node_1": "Age",
#         "node_2": "CAD in women",
#         "edge": "age as a risk factor for CAD in women"
#     },
#     {
#         "node_1": "After the age of 55",
#         "node_2": "risk for CAD increases similarly in both men and women",
#         "edge": "relationship between increasing age and risk for CAD"
#     },
#     {
#         "node_1": "Modifiable",
#         "node_2": "Smoking",
#         "edge": "one of the modifiable risk factors"
#     },
#     {
#         "node_1": "American Heart Association",
#         "node_2": "according to",
#         "edge": "source for information on smoking as a risk factor"
#     }
# ] [
#    {
#        "node_1": "CAD",
#        "node_2": "women smokers",
#        "edge": "Greater risk of CAD in women smokers"
#    }, {
#        "node_1": "women smokers",
#        "node_2": "men smokers",
#        "edge": "Percentage of women smokers lower than men smokers"
#    }, {
#        "node_1": "CAD",
#        "node_2": "male smokers",
#        "edge": "Greater risk of CAD in male smokers"
#    }, {
#        "node_1": "reduction in smoking",
#        "node_2": "decline in",
#        "edge": "Reduction in smoking accounted for a decline in"
#    }
# ] [
#     {
#         "node_1": "CAD",
#         "node_2": "Smoking",
#         "edge": "avoided by not smoking and avoiding environmental tobacco smoke"
#     },
#     {
#         "node_1": "CAD",
#         "node_2": "smoking cessation counseling",
#         "edge": "is advised for preventing CAD in women"
#     },
#     {
#         "node_1": "smoking cessation counseling",
#         "node_2": "pharmacotherapy options",
#         "edge": "are considered in conjunction with a formal smoking cessation program"
#     },
#     {
#         "node_1": "smoking cessation counseling",
#         "node_2": "encounter",
#         "edge": "should be advised at each encounter"
#     }
# ] [
#    {
#        "node_1": "Cardiovascular diseases",
#        "node_2": "leading cause of morbidity and mortality",
#        "edge": "among women worldwide"
#    },
#    {
#        "node_1": "pathophysiological basis",
#        "node_2": "cardiovascular health among men and women",
#        "edge": "is not identical"
#    },
#    {
#        "node_1": "variable cardiovascular responses",
#        "node_2": "to stimulus",
#        "edge": "presentation of cardiovascular disease symptoms"
#    }
# ] [
#     {
#         "node_1": "Enrollment of women",
#         "node_2": "Clinical trials",
#         "edge": "minimal enrollment in"
#     },
#     {
#         "node_1": "Lack of gender-specific analysis",
#         "node_2": "Clinical trial data",
#         "edge": "caused by minimal enrollment"
#     }
# ] [
#    {
#        "node_1": "absence of concrete risk factor assessment",
#        "node_2": "women",
#        "edge": "in the context"
#    }, {
#        "node_1": "scientific progress in the past decade",
#        "node_2": "identified a spectrum of risk factors for cardiovascular diseases specific to women",
#        "edge": "related in one sentence"
#    }, {
#        "node_1": "risk factors",
#        "node_2": "may include menopause, hypertensive disease of pregnancy, and depression",
#        "edge": "in the context"
#    }, {
#        "node_1": "additional risk in women",
#        "node_2": "traditional risk factors",
#        "edge": "related in one sentence"
#    }, {
#        "node_1": "current state of knowledge and awareness",
#        "node_2": "about these risk factors is suboptimal at this time",
#        "edge": "in the context"
#    }
# ] [
#   {
#        "node_1": "risk factors",
#        "node_2": "treatment of cardiovascular diseases",
#        "edge": "suboptimal at this time"
#    }
# ] [
#    {
#        "node_1": "appropriate risk stratification",
#        "node_2": "women compared to men",
#        "edge": "limited in women"
#    },
#    {
#        "node_1": "recent trends",
#        "node_2": "identifying female-specific risk factors for cardiovascular diseases",
#        "edge": ""
#    },
#    {
#        "node_1": "utility in risk stratification",
#        "node_2": "female-specific risk factors",
#        "edge": ""
#    },
#    {
#        "node_1": "pharmacological options for women",
#        "node_2": "cardiovascular disease prevention",
#        "edge": ""
#    }
# ] [
#    {
#        "node_1": "Obesity",
#        "node_2": "National Health and Nutrition Examination Survey (NHANES)",
#        "edge": "Obesity according to the 2013 NHANES"
#    },
#    {
#        "node_1": "Obesity",
#        "node_2": "U.S. adults aged ≥ 20 years",
#        "edge": "Among U.S. adults aged ≥ 20 years, Obesity"
#    },
#    {
#        "node_1": "Obesity",
#        "node_2": "37.7% were obese",
#        "edge": "37.7% of adults were obese"
#    },
#    {
#        "node_1": "Obesity",
#        "node_2": "metabolic syndrome",
#        "edge": "Obesity is thought to be related to metabolic syndrome"
#    },
#    {
#        "node_1": "CAD",
#        "node_2": "postmenopausal women",
#        "edge": "Impact of obesity on development of CAD in postmenopausal women"
#    },
#    {
#        "node_1": "CAD",
#        "node_2": "redistribution of fat around the abdominal area",
#        "edge": "Greater impact of obesity on CAD due to redistribution of fat"
#    },
#    {
#        "node_1": "CAD",
#        "node_2": "guidelines on CVD",
#        "edge": "The guidelines on CVD related to CAD"
#    }
# ] [
#    {
#        "node_1": "CVD prevention",
#        "node_2": "weight maintenance",
#        "edge": "should be maintained or lost through appropriate physical activity, caloric intake, and formal behavior programs"
#    }, {
#        "node_1": "CVD prevention",
#        "node_2": "goal body mass index (BMI)",
#        "edge": "of < 25 kg/m^2 in women or waist size < 35 inches"
#    }, {
#        "node_1": "CVD prevention",
#        "node_2": "recommended exercise time for women and men",
#        "edge": "is at least 150 minutes/week of moderate exercise or 75 minutes/week of vigorous exercise"
#    }, {
#        "node_1": "Endogenous estrogens",
#        "node_2": "Hypertension",
#        "edge": "maintain"
#    }
# ] [
#    {
#        "node_1": "Hypertension",
#        "node_2": "Endogenous estrogens",
#        "edge": "maintain vasodilation and contribute to blood pressure control"
#    }, {
#        "node_1": "Hypertension",
#        "node_2": "Age",
#        "edge": "risk increases more in elderly women than in elderly men"
#    }, {
#        "node_1": "Hypertension",
#        "node_2": "Race",
#        "edge": "significantly higher prevalence of hypertension independent of other factors"
#    }
# ] [
#    {
#        "node_1": "antihypertensive agents",
#        "node_2": "sex-specific analysis",
#        "edge": "not report"
#    }, {
#        "node_1": "BP target",
#        "node_2": "individuals aged 60 years and older without diabetes or chronic kidney disease",
#        "edge": "recommended for"
#    }
# ] [
#    {
#        "node_1": "TC ≥ 200 mg/dL",
#        "node_2": "TC ≥ 240 mg/dL",
#        "edge": "are related to each other in the context"
#    }, {
#        "node_1": "Women ≥ 20 years",
#        "node_2": "United States",
#        "edge": "are related to each other in the context"
#    }, {
#        "node_1": "LDL-C ≥ 130 mg/dL",
#        "node_2": "Women ≥ 20 years",
#        "edge": "are related to each other in the context"
#    }, {
#        "node_1": "HDL-C < 40 mg/dL",
#        "node_2": "Women ≥ 20 years",
#        "edge": "are related to each other in the context"
#    }, {
#        "node_1": "Elevated LDL-C, triglycerides, and non-HDL-C",
#        "node_2": "Low HDL-C",
#        "edge": "have all been associated with an increased risk for CVD in women as in men"
#    }, {
#        "node_1": "Centers for Disease Control and Prevention",
#        "node_2": "Recently reported",
#        "edge": "are related to each other in the context"
#    }
# ] [
#    {
#        "node_1": "women",
#        "node_2": "men",
#        "edge": "less likely to be prescribed statin therapy than"
#    },
#    {
#        "node_1": "CVD risk",
#        "node_2": "statin therapy",
#        "edge": "individuals with established CVD, LDL-C ≥  190 mg/dL, diabetes, or an established 10-year CVD risk ≥  7.5% based on the pooled"
#    },
#    {
#        "node_1": "American College of Cardiology",
#        "node_2": "AHA",
#        "edge": "recommend statin therapy"
#    }
# ] [
#    {
#        "node_1": "cohort risk equation",
#        "node_2": "10-year and lifetime atherosclerotic cardiovascular disease event risk",
#        "edge": "calculates"
#    }, {
#        "node_1": "statin therapy",
#        "node_2": "physician-patient discussion",
#        "edge": "based on"
#    }, {
#        "node_1": "statin therapy",
#        "node_2": "5% to 7.5% 10-year ASCVD risk",
#        "edge": "recommended for"
#    }, {
#        "node_1": "statin therapy",
#        "node_2": "other factors",
#        "edge": "those with"
#    }
# ] [
#    {
#        "node_1": "elevated calcium score",
#        "node_2": "family history of premature ASCVD",
#        "edge": "association"
#    },
#    {
#        "node_1": "elevated high-sensitivity C-reactive protein (hs-CRP)",
#        "node_2": "abnormal ankle-brachial index (ABI)",
#        "edge": "association"
#    },
#    {
#        "node_1": "Diabetes Mellitus",
#        "node_2": "hemoglobin A1c",
#        "edge": "parameter"
#    },
#    {
#        "node_1": "gender-based differences",
#        "node_2": "anatomical features",
#        "edge": "relationship"
#    },
#    {
#        "node_1": "vessel sizes",
#        "node_2": "women",
#        "edge": "difference"
#    },
#    {
#        "node_1": "vessel sizes",
#        "node_2": "men",
#        "edge": "comparison"
#    }
# ] [
#    {
#        "node_1": "left ventricular size",
#        "node_2": "men",
#        "edge": "smaller in women"
#    },
#    {
#        "node_1": "systolic function",
#        "node_2": "women",
#        "edge": "greater than men"
#    },
#    {
#        "node_1": "diastolic compliance",
#        "node_2": "women",
#        "edge": "less in women than men"
#    },
#    {
#        "node_1": "hormonal differences",
#        "node_2": "estrogen",
#        "edge": "predominantly influential in women"
#    },
#    {
#        "node_1": "hormonal differences",
#        "node_2": "testosterone",
#        "edge": "predominantly influential in men"
#    },
#    {
#        "node_1": "cardiovascular function differences",
#        "node_2": "women",
#        "edge": "reduced sympathetic and higher parasympathetic activity than men"
#    },
#    {
#        "node_1": "cardiovascular function differences",
#        "node_2": "men",
#        "edge": "higher sympathetic activity than women"
#    },
#    {
#        "node_1": "stroke volume",
#        "node_2": "women",
#        "edge": "10% lower than men"
#    }
# ] [
#    {
#        "node_1": "Cardiovascular adaptions",
#        "node_2": "Women have an increased pulse rate with increased cardiac output versus men, who have higher blood pressure in response to high stress.",
#        "edge": "the context refers to the cardiovascular adaptations found between women and men."
#    }, {
#        "node_1": "Cardiovascular adaptions",
#        "node_2": "Electrocardiographic findings Women have a longer corrected QT interval than men. Women have a shorter PR interval than men.",
#        "edge": "the context refers to the cardiovascular adaptations found in women compared to men through electrocardiographic findings."
#    }, {
#        "node_1": "Differences",
#        "node_2": "Table 1. Differences in clinical parameters and manifestations in women compared to men.",
#        "edge": "the context refers to the differences shown in Table 1."
#    }
# ] [
#    {
#        "node_1": "heart disease-related causes",
#        "node_2": "mortality due to heart disease-related causes in adults with DM",
#        "edge": "Relation in one sentence"
#    }, {
#        "node_1": "adverse CV outcomes",
#        "node_2": "(HbA1c)",
#        "edge": "Relation in one sentence"
#    }, {
#        "node_1": "mortality due to heart disease-related causes in adults with DM",
#        "node_2": "two to four times higher than in those without DM",
#        "edge": "Relation in one sentence"
#    }, {
#        "node_1": "CVD mortality",
#        "node_2": "significant gender difference in type 1 DM",
#        "edge": "Relation in one sentence"
#    }, {
#        "node_1": "type 1 DM",
#        "node_2": "affects women and men equally",
#        "edge": "Relation in one sentence"
#    }, {
#        "node_1": "women with type I DM",
#        "node_2": "37% increased",
#        "edge": "Relation in one sentence"
#    }
# ] [
#     {
#         "node_1": "risk of all-cause mortality",
#         "node_2": "twice the excess risk of fatal and nonfatal vascular events",
#         "edge": "compared to men with type I DM"
#     },
#     {
#         "node_1": "women with DM",
#         "node_2": "appropriate glycemic control",
#         "edge": "less likely to have"
#     },
#     {
#         "node_1": "women with DM",
#         "node_2": "aggressive treatment for many modifiable CAD risk factors",
#         "edge": "receive less compared to diabetic"
#     }
# ] [
#    {
#        "node_1": "ASCVD benefit",
#        "node_2": "intensive versus standard glycemic control",
#        "edge": "Clinical trial interventions have failed to demonstrate ASCVD benefit with intensive versus standard glycemic control"
#    }, {
#        "node_1": "SGLT-2 inhibitors",
#        "node_2": "CVD benefit",
#        "edge": "Recent trials with newer agents such as SGLT-2 inhibitors have started to show some benefit with respect to CVD"
#    }, {
#        "node_1": "HbA1c of < 7%",
#        "node_2": "Applicable guidelines",
#        "edge": "The current applicable guidelines recommend an HbA1c of < 7%, if achieved without causing significant hypoglycemia, for ASCVD risk reduction"
#    }, {
#        "node_1": "Hypertensive Disorders of Pregnancy",
#        "node_2": "NONTRADITIONAL RISK FACTORS",
#        "edge": "The NONTRADITIONAL RISK FACTORS include Hypertensive Disorders of Pregnancy"
#    }
# ] [
#    {
#        "node_1": "Hypertensive Disorders of Pregnancy",
#        "node_2": "Pregnancy",
#        "edge": "cause and effect"
#    },
#    {
#        "node_1": "Hypertensive Disorders of Pregnancy",
#        "node_2": "cardiometabolic stressor",
#        "edge": "related to"
#    },
#    {
#        "node_1": "Hypertensive Disorders of Pregnancy",
#        "node_2": "vascular and metabolic abnormalities",
#        "edge": "unmask underlying"
#    },
#    {
#        "node_1": "Hypertension",
#        "node_2": "Pregnancies",
#        "edge": "affects approximately 10% of"
#    },
#    {
#        "node_1": "Hypertension",
#        "node_2": "leading causes of maternal and fetal morbidity and mortality",
#        "edge": "cause for"
#    },
#    {
#        "node_1": "Gestational hypertensive disorders",
#        "node_2": "Diabetes",
#        "edge": "linked to increased risk of developing hypertension as well as cardiovascular disease later in life"
#    },
#    {
#        "node_1": "Hypertension",
#        "node_2": "cardiovascular disease (CVD)",
#        "edge": "increased risk for"
#    }
# ] [
#     {
#         "node_1": "gestational hypertension disorders",
#         "node_2": "preeclampsia",
#         "edge": "hypothesis of endothelial dysfunction, oxidative stress, inflammatory response, and increased expression of procoagulants"
#     },
#     {
#         "node_1": "preeclampsia",
#         "node_2": "CVD",
#         "edge": "share similar risk factors including obesity, insulin resistance, renal disease"
#     }
# ] [
#    {
#        "node_1": "ischemic heart disease",
#        "node_2": "CVD in women",
#        "edge": "has an increased relative risk for incidence of ischemic heart disease and may be independently associated with CVD in women"
#    },
#    {
#        "node_1": "preeclampsia",
#        "node_2": "CVD",
#        "edge": "recognized as a risk factor for CVD"
#    },
#    {
#        "node_1": "AHA",
#        "node_2": "American College of Obstetrics and Gynecology",
#        "edge": "both organizations are involved in recognizing and assessing related health issues"
#    },
#    {
#        "node_1": "yearly assessment",
#        "node_2": "blood pressure, lipids, fasting blood glucose, body mass index",
#        "edge": "annual evaluation of the mentioned factors following a medical condition or risk factor"
#    }
# ] [
#    {
#        "node_1": "history of recurrent preeclampsia",
#        "node_2": "preeclampsia with preterm birth",
#        "edge": "relationship between the two concepts, in one sentence"
#    },
#    {
#        "node_1": "women with a history of hypertensive disorders during pregnancy",
#        "node_2": "lifestyle modifications",
#        "edge": "relationship between the two concepts, in one sentence"
#    },
#    {
#        "node_1": "history of recurrent preeclampsia or preeclampsia with preterm birth",
#        "node_2": "more aggressive screening",
#        "edge": "relationship between the two concepts, in one sentence"
#    },
#    {
#        "node_1": "Gestational Diabetes",
#        "node_2": "Gestational diabetes mellitus (GDM)",
#        "edge": "relationship between the two concepts, in one sentence"
#    },
#    {
#        "node_1": "normal glucose metabolism",
#        "node_2": "after third trimester of pregnancy",
#        "edge": "relationship between the two concepts, in one sentence"
#    }
# ] [
#    {
#        "node_1": "pregnancy",
#        "node_2": "glucose metabolism",
#        "edge": "Returns to normal"
#    },
#    {
#        "node_1": "GDM",
#        "node_2": "diabetes mellitus",
#        "edge": "Patients with history have elevated risk"
#    },
#    {
#        "node_1": "screening and lifestyle modification",
#        "node_2": "more aggressive consideration",
#        "edge": "Recommended for patients with a history of GDM"
#    },
#    {
#        "node_1": "Systemic autoimmune disorders",
#        "node_2": "CVD",
#        "edge": "Associated with"
#    },
#    {
#        "node_1": "women",
#        "node_2": "men",
#        "edge": "Tend to affect more often"
#    },
#    {
#        "node_1": "rheumatoid arthritis",
#        "node_2": "patients with rheumatoid arthritis",
#        "edge": "Reported to have a"
#    }
# ] [
#    {
#        "node_1": "higher risk of myocardial infarction (MI)",
#        "node_2": "systemic lupus erythematosus",
#        "edge": "Increased the risk of MI between 9- and 50-fold over the general population"
#    }, {
#        "node_1": "higher risk of stroke",
#        "node_2": "systemic lupus erythematosus",
#        "edge": "Increased the risk of stroke by 50%"
#    }, {
#        "node_1": "inflammatory diseases",
#        "node_2": "microvasculature",
#        "edge": "Affect the microvasculature"
#    }, {
#        "node_1": "plaque instability",
#        "node_2": "inflammatory diseases",
#        "edge": "Result in plaque instability"
#    }, {
#        "node_1": "acute CV events",
#        "node_2": "inflammatory diseases",
#        "edge": "Increase the risk of acute CV events"
#    }, {
#        "node_1": "depression",
#        "node_2": "acute CV events",
#        "edge": "Postulated that depression affects microvasculature and can result in plaque instability, increasing the risk of acute CV events"
#    }
# ] [
#    {
#        "node_1": "Depression",
#        "node_2": "antecedent to heart disease",
#        "edge": "Described as an antecedent"
#    },
#    {
#        "node_1": "NHANES I study",
#        "node_2": "women with depression had a higher relative risk of CAD incidence compared to women without depression",
#        "edge": "study result"
#    },
#    {
#        "node_1": "depression",
#        "node_2": "CV risk factors such as smoking and physical inactivity",
#        "edge": "associated with"
#    },
#    {
#        "node_1": "women",
#        "node_2": "experience depression at approximately twice the rate of men",
#        "edge": "statistic"
#    },
#    {
#        "node_1": "depressed women",
#        "node_2": "higher risk for CVD",
#        "edge": "studies have suggested"
#    }
# ] [
#    {
#        "node_1": "depression",
#        "node_2": "non-depressed women",
#        "edge": "differentiation in context"
#    }, {
#        "node_1": "chest pain",
#        "node_2": "depression and anxiety disorders",
#        "edge": "association in presenting features"
#    }, {
#        "node_1": "tachycardia",
#        "node_2": "depression and anxiety disorders",
#        "edge": "association in presenting features"
#    }, {
#        "node_1": "clinically appropriate cardiac evaluation",
#        "node_2": "women with such symptoms",
#        "edge": "need for in context"
#    }, {
#        "node_1": "treatment of depression",
#        "node_2": "improve cardiac outcomes",
#        "edge": "uncertainty in context"
#    }
# ] [
#    {
#        "node_1": "Radiation therapy",
#        "node_2": "Breast cancer",
#        "edge": "treatment for"
#    }, {
#        "node_1": "Radiation therapy",
#        "node_2": "Cardiac mortality",
#        "edge": "associated with increased risk of"
#    }, {
#        "node_1": "Radiation therapy",
#        "node_2": "Cardiac morbidity",
#        "edge": "associated with increased risk of"
#    }
# ] [
#    {
#        "node_1": "Cigarette smoking",
#        "node_2": "Counselling for cessation",
#        "edge": "Counselling for cessation is a method to help people quit cigarette smoking"
#    },
#    {
#        "node_1": "Cigarette smoking",
#        "node_2": "Nicotine replacement",
#        "edge": "Nicotine replacement can be used as an aid to help people quit cigarette smoking"
#    },
#    {
#        "node_1": "Cigarette smoking",
#        "node_2": "Pharmacotherapy",
#        "edge": "Pharmacotherapy is a treatment method that can be applied in conjunction with cessation efforts for cigarette smoking"
#    },
#    {
#        "node_1": "Lifestyle intervention",
#        "node_2": "Physical activity",
#        "edge": "Physical activity is one component of a lifestyle intervention."
#    },
#    {
#        "node_1": "Physical activity",
#        "node_2": "Moderate exercise",
#        "edge": "Moderate exercise is one form of physical activity recommended in a lifestyle intervention."
#    },
#    {
#        "node_1": "Physical activity",
#        "node_2": "Vigorous exercise",
#        "edge": "Vigorous exercise is another form of physical activity recommended in a lifestyle intervention."
#    },
#    {
#        "node_1": "Physical activity",
#        "node_2": "Muscle strengthening activities",
#        "edge": "Muscle strengthening activities are an additional component of physical activity in a lifestyle intervention."
#    }
# ] [
#    {
#        "node_1": "Cardiac rehabilitation",
#        "node_2": "Recent acute coronary syndrome",
#        "edge": "Recommended for women with"
#    },
#    {
#        "node_1": "Cardiac rehabilitation",
#        "node_2": "Revascularization",
#        "edge": "Recommended for women with"
#    },
#    {
#        "node_1": "Cardiac rehabilitation",
#        "node_2": "CVA",
#        "edge": "Recommended for women with"
#    },
#    {
#        "node_1": "Cardiac rehabilitation",
#        "node_2": "PAD",
#        "edge": "Recommended for women with"
#    },
#    {
#        "node_1": "BMI",
#        "node_2": "< 25 kg/m",
#        "edge": "Recommended to maintain by exercise and appropriate diet"
#    },
#    {
#        "node_1": "Waist size",
#        "node_2": "< 35 inches",
#        "edge": "Recommended to maintain by exercise and appropriate diet"
#    },
#    {
#        "node_1": "CLINICAL RISK FACTORS TARGETS AND USES IN RISK ASSESSMENT",
#        "node_2": "Blood pressure < 140/90 mm Hg",
#        "edge": "Recommended"
#    },
#    {
#        "node_1": "High Blood pressure",
#        "node_2": "Consider therapy from one of the indicated classes of antihypertensive drugs",
#        "edge": "If higher,"
#    }
# ] [
#    {
#        "node_1": "LDL-C",
#        "node_2": "70-189 mg/dL",
#        "edge": "at baseline"
#    }, {
#        "node_1": "between 70-189 mg/dL",
#        "node_2": "without clinical ASCVD",
#        "edge": "in ages 40-75 years"
#    }, {
#        "node_1": "ASCVD risk score",
#        "node_2": "≥ 7.5%",
#        "edge": "consider statins for"
#    }, {
#        "node_1": "statins",
#        "node_2": "high-intensity statin therapy",
#        "edge": "warrant due to higher risk"
#    }, {
#        "node_1": "ASCVD risk factors",
#        "node_2": "10-year ASCVD risk ≥ 7.5%",
#        "edge": "indicate higher risk and warrant high-intensity statin therapy ± ezetimibe (or colesevelam)"
#    }, {
#        "node_1": "CKD",
#        "node_2": "albuminuria",
#        "edge": "retinopathy, evidence of subclinical atherosclerosis, elevated lipoprotein(a), or elevated hs-CRP"
#    }, {
#        "node_1": "evidence of subclinical atherosclerosis",
#        "node_2": "elevated hs-CRP",
#        "edge": "indicate higher risk and warrant high-intensity statin therapy ± ezetimibe (or colesevelam)"
#    }, {
#        "node_1": "elevated lipoprotein(a)",
#        "node_2": "elevated hs-CRP",
#        "edge": "indicate higher risk and warrant high-intensity statin therapy ± ezetimibe (or colesevelam)"
#    }, {
#        "node_1": "ezetimibe",
#        "node_2": "colesevelam",
#        "edge": "high-intensity statin therapy"
#    }
# ] [
#    {
#        "node_1": "Statin use",
#        "node_2": "Moderate to high intensity",
#        "edge": "recommended at any LDL-C level in patients of ages < 75 years with established ASCVD"
#    }, {
#        "node_1": "LDL-C level",
#        "node_2": "Patients of ages < 75 years",
#        "edge": "with established ASCVD"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Optimal",
#        "edge": "< 100 mg/dL"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Normal",
#        "edge": "< 150 mg/dL"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Elevated",
#        "edge": "≥ 150 mg/dL"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Treat",
#        "edge": "if ≥ 500 mg/dL (after ruling out secondary causes)"
#    }, {
#        "node_1": "Diabetes mellitus",
#        "node_2": "Lifestyle and pharmacotherapy",
#        "edge": "are recommended to achieve an HbA1c of < 7%"
#    }, {
#        "node_1": "Concomitant use of statin",
#        "node_2": "Recommended",
#        "edge": "in patients with diabetes mellitus"
#    }, {
#        "node_1": "HDL-C",
#        "node_2": "50 mg/dL in women",
#        "edge": "is a risk marker of ASCVD"
#    }, {
#        "node_1": "Hs-CRP",
#        "node_2": "3.0 mg/dL",
#        "node_3": "high relative risk"
#        "edge": "> 3.0 mg/dL"
#    }
# ]
#
# ERROR ### Here is the buggy response:   [
#    {
#        "node_1": "Statin use",
#        "node_2": "Moderate to high intensity",
#        "edge": "recommended at any LDL-C level in patients of ages < 75 years with established ASCVD"
#    }, {
#        "node_1": "LDL-C level",
#        "node_2": "Patients of ages < 75 years",
#        "edge": "with established ASCVD"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Optimal",
#        "edge": "< 100 mg/dL"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Normal",
#        "edge": "< 150 mg/dL"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Elevated",
#        "edge": "≥ 150 mg/dL"
#    }, {
#        "node_1": "Triglycerides",
#        "node_2": "Treat",
#        "edge": "if ≥ 500 mg/dL (after ruling out secondary causes)"
#    }, {
#        "node_1": "Diabetes mellitus",
#        "node_2": "Lifestyle and pharmacotherapy",
#        "edge": "are recommended to achieve an HbA1c of < 7%"
#    }, {
#        "node_1": "Concomitant use of statin",
#        "node_2": "Recommended",
#        "edge": "in patients with diabetes mellitus"
#    }, {
#        "node_1": "HDL-C",
#        "node_2": "50 mg/dL in women",
#        "edge": "is a risk marker of ASCVD"
#    }, {
#        "node_1": "Hs-CRP",
#        "node_2": "3.0 mg/dL",
#        "node_3": "high relative risk"
#        "edge": "> 3.0 mg/dL"
#    }
# ]
#
#
#  [
#    {
#        "node_1": "Hs-CRP > 3.0 mg/dL",
#        "node_2": "high relative risk",
#        "edge": "high Hs-CRP level indicates higher relative risk"
#    }, {
#        "node_1": "CAC scoring",
#        "node_2": "disease severity",
#        "edge": "CAC scoring is used to determine the severity of identifiable disease"
#    }, {
#        "node_1": "CIMT",
#        "node_2": "routine ASCVD risk assessment",
#        "edge": "CIMT is not recommended for routine ASCVD risk assessment"
#    }, {
#        "node_1": "aspirin",
#        "node_2": "recommended therapy",
#        "edge": "Aspirin is recommended therapy"
#    }, {
#        "node_1": "USPTF",
#        "node_2": "women aged 50-59 years",
#        "edge": "USPTF recommends aspirin for women aged 50-59 years"
#    }, {
#        "node_1": "10% or greater 10-year CVD risk",
#        "node_2": "women aged 50-59 years",
#        "edge": "Women with 10% or greater 10-year CVD risk benefit from aspirin therapy"
#    }, {
#        "node_1": "expert opinion",
#        "node_2": "2013 ACC/AHA Guidelines",
#        "edge": "Recommendations are based on expert opinion in 2013 ACC/AHA Guidelines"
#    }
# ] [
#    {
#        "node_1": "cardiovascular diseases",
#        "node_2": "women",
#        "edge": "interventions for prevention"
#    }, {
#        "node_1": "cerebrovascular accident",
#        "node_2": "current guidelines",
#        "edge": "assessment and interventions based on"
#    }
# ] [
#    {
#        "node_1": "includes stroke or transient ischemic attack",
#        "node_2": "PAD: peripheral arterial disease",
#        "edge": "are both risk factors"
#    }, {
#        "node_1": "BMI: body mass index",
#        "node_2": "ASCVD: atherosclerotic cardiovascular disease",
#        "edge": "affects the risk of"
#    }, {
#        "node_1": "CKD: chronic kidney disease",
#        "node_2": "hs-CRP: high-sensitivity C-reactive protein",
#        "edge": "is associated with"
#    }, {
#        "node_1": "LDL-C: low-density lipoprotein cholesterol",
#        "node_2": "HDL-C: high-density lipoprotein cholesterol",
#        "edge": "are types of cholesterol"
#    }, {
#        "node_1": "CAC: coronary artery calcium",
#        "node_2": "CIMT : carotid intima–media thickness",
#        "edge": "are used to assess atherosclerosis risk"
#    }, {
#        "node_1": "USPTF: United States Preventive Services Task Force",
#        "node_2": null,
#        "edge": "recommends guidelines for prevention and screening"
#    }
# ] [
#    {
#        "node_1": "Radiation injury",
#        "node_2": "Constrictive pericarditis",
#        "edge": "cause"
#    },
#    {
#        "node_1": "Radiation injury",
#        "node_2": "Myocardial fibrosis",
#        "edge": "cause"
#    },
#    {
#        "node_1": "Radiation injury",
#        "node_2": "Valvular and coronary artery lesions",
#        "edge": "cause"
#    },
#    {
#        "node_1": "Increased risk of cardiovascular mortality",
#        "node_2": "Dose volume of exposure to the heart",
#        "edge": "proportional to"
#    }
# ] [
#    {
#        "node_1": "postoperative radiation therapy",
#        "node_2": "cardiac mortality",
#        "edge": "positively correlated"
#    },
#    {
#        "node_1": "high-dose volumes",
#        "node_2": "increased mortality",
#        "edge": "caused by"
#    },
#    {
#        "node_1": "cardiac radiation dose-volume",
#        "node_2": "ischemic heart disease",
#        "edge": "related to"
#    },
#    {
#        "node_1": "preexisting cardiac risk factors",
#        "node_2": "radiotherapy",
#        "edge": "greater absolute increase in risk from"
#    }
# ] [
#    {
#        "node_1": "radiotherapy regimens for breast cancer",
#        "node_2": "women with breast cancer who have undergone therapy",
#        "edge": "treatment"
#    }, {
#        "node_1": "radiation",
#        "node_2": "consideration in women with breast cancer",
#        "edge": "impact"
#    }, {
#        "node_1": "estrogen",
#        "node_2": "estrogen receptors expressed both in vascular endothelial and smooth muscle cells",
#        "edge": "role"
#    }, {
#        "node_1": "estrogen",
#        "node_2": "improves the arterial wall response to injury",
#        "edge": "benefit"
#    }, {
#        "node_1": "estrogen",
#        "node_2": "promotes re-endothelialization",
#        "edge": "function"
#    }
# ] [
#    {
#        "node_1": "smooth muscle cell proliferation",
#        "node_2": "matrix deposition following vascular injury",
#        "edge": "inhibits"
#    }, {
#        "node_1": "Estrogen",
#        "node_2": "coronary artery spasm",
#        "edge": "prevents through vasodilation mediated by"
#    }, {
#        "node_1": "Estrogen",
#        "node_2": "nitric oxide (NO)",
#        "edge": "increases the production of"
#    }, {
#        "node_1": "Estrogen",
#        "node_2": "NO genes",
#        "edge": "induction of"
#    }, {
#        "node_1": "Estrogen",
#        "node_2": "endothelium and smooth muscle cells",
#        "edge": "impact on"
#    }, {
#        "node_1": "Estrogen",
#        "node_2": "cardiomyocytes",
#        "edge": "affects"
#    }, {
#        "node_1": "Estrogen",
#        "node_2": "cardiomyocyte apoptosis",
#        "edge": "prevents"
#    }
# ] [
#    {
#        "node_1": "cardiomyocyte hypertrophic response",
#        "node_2": "estrogen",
#        "edge": "inhibits"
#    }, {
#        "node_1": "conflicting data",
#        "node_2": "hypertrophic response",
#        "edge": "on"
#    }, {
#        "node_1": "postmenopausal women",
#        "node_2": "cardioprotective effects of estrogen",
#        "edge": "lose"
#    }, {
#        "node_1": "elevated risk for CVD",
#        "node_2": "postmenopausal women",
#        "edge": "have an"
#    }, {
#        "node_1": "ACC and AHA",
#        "node_2": "menopause as a risk factor",
#        "edge": "recognize"
#    }, {
#        "node_1": "HRT",
#        "node_2": "evidence for promoting",
#        "edge": "controversial"
#    }, {
#        "node_1": "Women’s Health Initiative (WHI) study",
#        "node_2": "estrogen-progestin replacement",
#        "edge": "had no cardioprotective"
#    }
# ] [
#    {
#        "node_1": "Harm",
#        "node_2": "HRT",
#        "edge": "effect and may have produced"
#    }, {
#        "node_1": "Secondary prevention cohort",
#        "node_2": "HERS trials",
#        "edge": "Similar results in a"
#    }, {
#        "node_1": "HRT",
#        "node_2": "Primary or secondary prevention of CVD",
#        "edge": "not recommended for"
#    }, {
#        "node_1": "Usage of HRT",
#        "node_2": "WHI findings",
#        "edge": "As a result, has decreased"
#    }, {
#        "node_1": "Treatment decisions",
#        "node_2": "Perimenopausal women in their 40s and 50s with distressing vasomotor symptoms",
#        "edge": "These findings have also affected"
#    }
# ] [
#    {
#        "node_1": "USPSTF",
#        "node_2": "recommendations",
#        "edge": "applies to"
#    }, {
#        "node_1": "women under age 50",
#        "node_2": "HRT for treatment of menopausal symptoms",
#        "edge": "do not apply to"
#    }, {
#        "node_1": "risks and benefits",
#        "node_2": "patient",
#        "edge": "should be considered and discussed with"
#    }
# ] [
#    {
#        "node_1": "pooled cohort risk equation",
#        "node_2": "10-year CVD risk",
#        "edge": "used to assess"
#    },
#    {
#        "node_1": "United States",
#        "node_2": "current recommendation",
#        "edge": "for use in"
#    },
#    {
#        "node_1": "future",
#        "node_2": "nontraditional risk factors and markers",
#        "edge": "should be considered with"
#    },
#    {
#        "node_1": "depression",
#        "node_2": "radiation exposure",
#        "edge": "among other nontraditional risk factors"
#    }
# ] [
#    {
#        "node_1": "treatment thresholds",
#        "node_2": "men and women",
#        "edge": "similar in men and women will need to be further explored"
#    },
#    {
#        "node_1": "2011 effectiveness-based guidelines",
#        "node_2": "women",
#        "edge": "recommended different CVD prevention and treatment strategies specific to women compared to men"
#    },
#    {
#        "node_1": "2013 ACC/AHA lipid guidelines",
#        "node_2": "men and women",
#        "edge": "have similar recommendations for men and women"
#    },
#    {
#        "node_1": "CAROTID INTIMA-MEDIA THICKNESS",
#        "node_2": "risk markers",
#        "edge": "Ten-year risk assessments still have room for improvement; thus"
#    }
# ] [
#    {
#        "node_1": "genetic biomarkers",
#        "node_2": "serum biomarkers",
#        "edge": "both have been extensively studied in risk stratification"
#    }, {
#        "node_1": "imaging",
#        "node_2": "carotid ultrasound and coronary computed tomography (CT)",
#        "edge": "have been extensively studied in risk stratification"
#    }, {
#        "node_1": "risk stratification",
#        "node_2": "genetic biomarkers, serum biomarkers, imaging such as carotid ultrasound and coronary computed tomography (CT)",
#        "edge": "are used in"
#    }, {
#        "node_1": "carotid intima-media thickness (CIMT)/plaque information on a carotid ultrasound",
#        "node_2": "risk prediction for CVD",
#        "edge": "improves"
#    }, {
#        "node_1": "2010 ACCF/AHA Guideline",
#        "node_2": "endorsed assessment of carotid intima-media thickness (CIMT)/plaque information on a carotid ultrasound",
#        "edge": "for Assessment of Cardiovascular Risk in Asymptomatic Adults"
#    }, {
#        "node_1": "2013",
#        "node_2": "not recommended by the 2010 ACCF/AHA Guideline for Assessment of Cardiovascular Risk in Asymptomatic Adults",
#        "edge": ""
#    }
# ] [
#    {
#        "node_1": "CT-based coronary calcium score (CAC)",
#        "node_2": "threshold for initiating statin therapy",
#        "edge": "recommended by the ACC/AHA 2013 lipid guidelines"
#    }, {
#        "node_1": "ACC/AHA 2013 lipid guidelines",
#        "node_2": "hypothesis",
#        "edge": ""
#    }
# ] [
#    {
#        "node_1": "brachial index",
#        "node_2": "treatment decisions",
#        "edge": "help to assist"
#    }, {
#        "node_1": "brachial index",
#        "node_2": "uncertainty",
#        "edge": "after quantitative risk assessment"
#    }, {
#        "node_1": "therapies for primary prevention of CVD",
#        "node_2": "statins in prevention",
#        "edge": "to treat"
#    }, {
#        "node_1": "JUPITER trial",
#        "node_2": "individuals with a C-reactive protein > 2 mg/dL",
#        "edge": "included"
#    }, {
#        "node_1": "JUPITER trial",
#        "node_2": "LDL-C < 130 mg/dL",
#        "edge": "also included"
#    }
# ] [
#    {
#        "node_1": "REVIEW METHODIST DEBAKEY CARDIOVASC J",
#        "node_2": "13 (4) 2017",
#        "edge": "is part of"
#    },
#    {
#        "node_1": "JOURNAL.HOUSTONMETHODIST.ORG",
#        "node_2": "REVIEW METHODIST DEBAKEY CARDIOVASC J",
#        "edge": "hosting the journal"
#    },
#    {
#        "node_1": "HOPE-3 trial",
#        "node_2": "intermediate-risk subjects without known CVD",
#        "edge": "focuses on"
#    },
#    {
#        "node_1": "statins help in the primary prevention of CVD",
#        "node_2": "HOPE-3 trial",
#        "edge": "results from"
#    },
#    {
#        "node_1": "benefit occurs in both men and women",
#        "node_2": "statins help in the primary prevention of CVD",
#        "edge": "explains"
#    }
# ] [
#    {
#        "node_1": "CVD",
#        "node_2": "prevention",
#        "edge": "The primary and secondary prevention of CVD is valuable in both men and women."
#    }, {
#        "node_1": "statin safety data",
#        "node_2": "pregnancy",
#        "edge": "There is a lack of statin safety data in pregnancy."
#    }, {
#        "node_1": "women of childbearing age",
#        "node_2": "counseling",
#        "edge": "These women need to be thoroughly counseled on contraceptive use."
#    }, {
#        "node_1": "contraceptive use",
#        "node_2": "avoid pregnancy",
#        "edge": "Contraceptive use is needed to avoid pregnancy while on statin therapy."
#    }, {
#        "node_1": "statin therapy",
#        "node_2": "secondary prevention of CVD",
#        "edge": "The use of statin therapy is for the secondary prevention of CVD."
#    }
# ] [
#    {
#        "node_1": "aspirin",
#        "node_2": "prevention",
#        "edge": "established"
#    }, {
#        "node_1": "aspirin",
#        "node_2": "data supporting aspirin use",
#        "edge": "supporting"
#    }, {
#        "node_1": "aspirin",
#        "node_2": "men",
#        "edge": "mainly reported in men before 2005"
#    }, {
#        "node_1": "aspirin",
#        "node_2": "women",
#        "edge": "studied in women after 2005"
#    }, {
#        "node_1": "aspirin",
#        "node_2": "low-dose aspirin",
#        "edge": "100 mg alternate-day dosing"
#    }
# ] [
#    {
#        "node_1": "dose aspirin",
#        "node_2": "risk of stroke",
#        "edge": "reduced without reducing MI"
#    },
#    {
#        "node_1": "age",
#        "node_2": "determinant",
#        "edge": "most important"
#    },
#    {
#        "node_1": "low-dose aspirin",
#        "node_2": "risk of major cardiovascular events",
#        "edge": "significantly reduced"
#    },
#    {
#        "node_1": "women > 65 years old",
#        "node_2": "group benefited",
#        "edge": "particularly for this group"
#    },
#    {
#        "node_1": "aspirin therapy",
#        "node_2": "higher bleeding risk",
#        "edge": "those assigned to aspirin therapy had"
#    },
#    {
#        "node_1": "risk and benefits",
#        "node_2": "weighed",
#        "edge": "the risk and benefits of aspirin therapy should be weighed"
#    },
#    {
#        "node_1": "patient",
#        "node_2": "has risk factors for bleeding",
#        "edge": "particularly if a patient has risk factors for bleeding"
#    }
# ] [
#    {
#        "node_1": "low-dose aspirin",
#        "node_2": "type 2 DM",
#        "edge": "used in patients with type 2 DM"
#    }, {
#        "node_1": "low-dose aspirin",
#        "node_2": "primary prevention of CVD",
#        "edge": "evaluated for long-term safety and efficacy in preventing CVD"
#    }, {
#        "node_1": "low-dose aspirin",
#        "node_2": "CV outcomes",
#        "edge": "did not improve CV outcomes"
#    }, {
#        "node_1": "low-dose aspirin",
#        "node_2": "gastrointestinal bleeding",
#        "edge": "increased the risk of gastrointestinal bleeding"
#    }, {
#        "node_1": "statin use",
#        "node_2": "individuals",
#        "edge": "statin use among these individuals"
#    }, {
#        "node_1": "statin use",
#        "node_2": "lower LDL-C",
#        "edge": "reduced previously known aspirin benefit"
#    }
# ] [
#    {
#        "node_1": "U.S. Preventive Services Task Force",
#        "node_2": "recommended the use of low-dose aspirin",
#        "edge": "for primary prevention in both women and men aged 50 to 59 years who have a 10% or greater 10-year CVD risk without an increased risk of bleeding"
#    }, {
#        "node_1": "low-dose aspirin",
#        "node_2": "for primary prevention in both women and men aged 50 to 59 years who have a 10% or greater 10-year CVD risk without an increased risk of bleeding",
#        "edge": "Grade B recommendation"
#    }, {
#        "node_1": "primary prevention",
#        "node_2": "in both women and men aged 50 to 59 years who have a 10% or greater 10-year CVD risk without an increased risk of bleeding",
#        "edge": "U.S. Preventive Services Task Force recommendation"
#    }, {
#        "node_1": "women and men aged 50 to 59 years who have a 10% or greater 10-year CVD risk without an increased risk of bleeding",
#        "node_2": "other preventive recommendations including management of hypertension and diabetes and smoking cessation",
#        "edge": ""
#    }
# ] [
#    {
#        "node_1": "Women",
#        "node_2": "Cardiovascular clinical trials",
#        "edge": "underrepresentation in therapeutic strategies"
#    }, {
#        "node_1": "Single-sex studies",
#        "node_2": "Female participation",
#        "edge": "increased substantially"
#    }, {
#        "node_1": "Mixed-gender trials",
#        "node_2": "Women",
#        "edge": "less than a third of participants"
#    }, {
#        "node_1": "Postulated reasons",
#        "node_2": "Low female participation",
#        "edge": "in research enrollment"
#    }
# ] [
#    {
#        "node_1": "enrollment",
#        "node_2": "underestimated cardiac risk in women and atypical cardiac disease presentation",
#        "edge": "include"
#    }, {
#        "node_1": "underestimated cardiac risk in women and atypical cardiac disease presentation",
#        "node_2": "reduced referrals to cardiology practices",
#        "edge": "result"
#    }, {
#        "node_1": "reduced referrals to cardiology practices",
#        "node_2": "recruitment for CV clinical trials is performed",
#        "edge": "where"
#    }, {
#        "node_1": "women manifest CVD later in life, and an age-gender bias may be present during the study enrollment process",
#        "node_2": "enrollment",
#        "edge": "mentioned"
#    }, {
#        "node_1": "other possible barriers to the recruitment of women",
#        "node_2": "enrollment",
#        "edge": "Other"
#    }
# ] [
#    {
#        "node_1": "fear and distrust",
#        "node_2": "research enterprise",
#        "edge": "caused by"
#    }, {
#        "node_1": "lack of knowledge",
#        "node_2": "participation in research",
#        "edge": "due to"
#    }, {
#        "node_1": "lack of transportation",
#        "node_2": "study participation",
#        "edge": "inhibits"
#    }, {
#        "node_1": "interference with work or family responsibilities",
#        "node_2": "study participation",
#        "edge": "causes"
#    }, {
#        "node_1": "subject burden",
#        "node_2": "study participation",
#        "edge": "results in"
#    }, {
#        "node_1": "financial costs",
#        "node_2": "study participation",
#        "edge": "imposes"
#    }, {
#        "node_1": "preventive therapies for CVD",
#        "node_2": "reducing mortality",
#        "edge": "achieves"
#    }, {
#        "node_1": "preventive therapies for CVD",
#        "node_2": "preserving cardiovascular health in women",
#        "edge": "goal of"
#    }
# ] [
#    {
#        "node_1": "CVD",
#        "node_2": "leading cause of death",
#        "edge": "CVD is the leading cause of death"
#    }, {
#        "node_1": "CVD",
#        "node_2": "United States",
#        "edge": "CVD is the leading cause of death in the United States"
#    }, {
#        "node_1": "scientific community",
#        "node_2": "robust progress",
#        "edge": "The scientific community has made robust progress"
#    }, {
#        "node_1": "CVD",
#        "node_2": "pathophysiology of CVD in women",
#        "edge": "The scientific community has made progress recognizing the clear differences in pathophysiology of CVD in women"
#    }, {
# ...
#        "edge": "potentially through"
#    }, {
#        "node_1": "mTOR control of protein translation and cell size",
#        "node_2": "blocking",
#        "edge": "by mTOR signaling"
#    }
# ] [
#    {
#        "node_1": "PI3K/AKT signaling pathway",
#        "node_2": "hypoxia-induced angiogenesis in tumors",
#        "edge": "regulates"
#    },
#    {
#        "node_1": "PI3K/AKT signaling pathway",
#        "node_2": "hypoxia-inducible factor-1 α stabilization",
#        "edge": "mediates"
#    },
#    {
#        "node_1": "PI3K/AKT signaling pathway",
#        "node_2": "vascular endothelial growth factor (VEGF) expression",
#        "edge": "regulates"
#    },
#    {
#        "node_1": "PI3K/AKT signaling pathway",
#        "node_2": "PI3K/AKT inhibitors LY294002 and wortmannin",
#        "edge": "inhibition of"
#    },
#    {
#        "node_1": "North and Sinclair Page 8",
#        "node_2": "Circ Res",
#        "edge": "from"
#    }
# ] [
#     {
#         "node_1": "NIH-PA Author Manuscript",
#         "node_2": "Manuscript",
#         "edge": "is a type of"
#     }
# ] [
#    {
#        "node_1": "mTOR inhibitor",
#        "node_2": "rapamycin",
#        "edge": "is"
#    },
#    {
#        "node_1": "decreases in VEGF secretion",
#        "node_2": "rapamycin treatment",
#        "edge": "causes"
#    },
#    {
#        "node_1": "mTOR",
#        "node_2": "autophagy",
#        "edge": "negatively regulates"
#    },
#    {
#        "node_1": "nutrient-poor conditions",
#        "node_2": "rapamycin treatment",
#        "edge": "inhibits mTOR"
#    },
#    {
#        "node_1": "autophagy",
#        "node_2": "destruction of defective molecules and organelles",
#        "edge": "allows for"
#    },
#    {
#        "node_1": "health of cardiovascular tissues",
#        "node_2": "autophagy",
#        "edge": "promotes"
#    },
#    {
#        "node_1": "PI3K/AKT/mTOR pathway",
#        "node_2": "numerous signaling pathways",
#        "edge": "lies at the intersections of"
#    }
# ] [
#    {
#        "node_1": "positioning this pathway",
#        "node_2": "vital mediator of aging and the cardiovascular system",
#        "edge": "relationship within the same sentence"
#    }, {
#        "node_1": "BubR1",
#        "node_2": "serine/threonine protein kinase",
#        "edge": "relationship within the same sentence"
#    }, {
#        "node_1": "BubR1",
#        "node_2": "inhibitor of the anaphase-promoting complex",
#        "edge": "relationship within the same sentence"
#    }, {
#        "node_1": "BubR1",
#        "node_2": "regulating the mitotic spindle assembly checkpoint",
#        "edge": "relationship within the same sentence"
#    }, {
#        "node_1": "heterozygous mice",
#        "node_2": "develop normally",
#        "edge": "relationship within the same sentence"
#    }, {
#        "node_1": "homozygous BubR1 hypomorphic mice",
#        "node_2": "develop premature aging phenotypes",
#        "edge": "relationship within the same sentence"
#    }
# ] [
#    {
#        "node_1": "BubR1 hypomorphic mice",
#        "node_2": "arrhythmias",
#        "edge": "exhibit"
#    },
#    {
#        "node_1": "arrhythmias",
#        "node_2": "death",
#        "edge": "primary mechanism leading to their death"
#    },
#    {
#        "node_1": "loss-of-BubR1 mice",
#        "node_2": "arterial wall thickness",
#        "edge": "reduced"
#    },
#    {
#        "node_1": "loss-of-BubR1 mice",
#        "node_2": "inner diameter",
#        "edge": "reduced"
#    },
#    {
#        "node_1": "loss-of-BubR1 mice",
#        "node_2": "fibrosis",
#        "edge": "increased"
#    },
#    {
#        "node_1": "loss-of-BubR1 mice",
#        "node_2": "elastic properties",
#        "edge": "reduced"
#    },
#    {
#        "node_1": "Cardiovascular Aging Review Series",
#        "node_2": "role",
#        "edge": "plays in the heart"
#    }
# ] [
#    {
#        "node_1": "Cardiovascular Aging Review Series",
#        "node_2": "mechanisms by which aging and obesity reduce cardiovascular function",
#        "edge": "discussed in the context"
#    },
#    {
#        "node_1": "understanding mechanisms",
#        "node_2": "combat cardiovascular disease",
#        "edge": "aim of the work discussed"
#    },
#    {
#        "node_1": "first part",
#        "node_2": "series",
#        "edge": "division of discussion in series"
#    },
#    {
#        "node_1": "Leeuwenburgh, Marzetti, and colleagues",
#        "node_2": "mitochondrial dysfunction and deregulated autophagy",
#        "edge": "examined involvement of concepts in cardiovascular aging"
#    },
#    {
#        "node_1": "extensive evidence",
#        "node_2": "supporting the concepts",
#        "edge": "used to support the concepts"
#    }
# ] [
#    {
#        "node_1": "mitochondrial function",
#        "node_2": "age",
#        "edge": "declines with age"
#    }, {
#        "node_1": "triggering cause",
#        "node_2": "molecular mechanism",
#        "edge": "of age-associated mitochondrial decline is unclear"
#    }, {
#        "node_1": "functional consequences",
#        "node_2": "cellular and tissue levels",
#        "edge": "have been well documented"
#    }, {
#        "node_1": "mitochondria",
#        "node_2": "energy generation",
#        "edge": "generate energy through oxidative phosphorylation"
#    }, {
#        "node_1": "byproduct",
#        "node_2": "increase in ROS production",
#        "edge": ""
#    }, {
#        "node_1": "free radical– imposed damage",
#        "node_2": "ROS production",
#        "edge": "is a byproduct"
#    }
# ] [
#    {
#        "node_1": "macromolecules",
#        "node_2": "cellular components",
#        "edge": "Control of mitochondria quality can occur at 3 basic stages"
#    },
#    {
#        "node_1": "mitochondria",
#        "node_2": "quality control",
#        "edge": "Control of mitochondria quality can occur at 3 basic stages"
#    },
#    {
#        "node_1": "repair",
#        "node_2": "damaged mitochondria",
#        "edge": "repair of damaged mitochondria"
#    },
#    {
#        "node_1": "removal",
#        "node_2": "dysfunctional mitochondria",
#        "edge": "removal of dysfunctional mitochondria through autophagy"
#    },
#    {
#        "node_1": "autophagy",
#        "node_2": "dysfunctional mitochondria",
#        "edge": "generation of new mitochondria through biogenesis"
#    },
#    {
#        "node_1": "biogenesis",
#        "node_2": "new mitochondria",
#        "edge": "role that autophagy plays"
#    }
# ] [
#    {
#        "node_1": "controlling mitochondria quality",
#        "node_2": "cardiac hypertrophy",
#        "edge": "discussed in the context of"
#    },
#    {
#        "node_1": "controlling mitochondria quality",
#        "node_2": "ischemia",
#        "edge": "discussed in the context of"
#    },
#    {
#        "node_1": "controlling mitochondria quality",
#        "node_2": "heart failure",
#        "edge": "discussed in the context of"
#    },
#    {
#        "node_1": "controlling mitochondria quality",
#        "node_2": "diabetic cardiomyopathy",
#        "edge": "discussed in the context of"
#    },
#    {
#        "node_1": "growth factors",
#        "node_2": "cardiovascular aging",
#        "edge": "role in"
#    },
#    {
#        "node_1": "molecular genetics",
#        "node_2": "lifespan extension",
#        "edge": "pertaining to"
#    }
# ] [
#    {
#        "node_1": "loss of insulin-like growth factor 1 (IGF-1) signaling",
#        "node_2": "lifespan extension in C elegans",
#        "edge": "led to"
#    }, {
#        "node_1": "IGF-1 pathways",
#        "node_2": "MAPK and mTOR pathways",
#        "edge": "regulate downstream"
#    }, {
#        "node_1": "IGF-1 pathways",
#        "node_2": "cell growth, proliferation, and survival",
#        "edge": "leading to effects on"
#    }, {
#        "node_1": "IGF-1 pathways",
#        "node_2": "lipid and glucose metabolism",
#        "edge": "in addition to"
#    }, {
#        "node_1": "role of IGF-1 in cardiac function and aging",
#        "node_2": "unknown",
#        "edge": "is largely"
#    }, {
#        "node_1": "recent data",
#        "node_2": "complex picture",
#        "edge": "present"
#    }
# ] [
#    {
#        "node_1": "growth factors",
#        "node_2": "cardiovascular health",
#        "edge": "influences"
#    },
#    {
#        "node_1": "clinical studies",
#        "node_2": "associations",
#        "edge": "relies heavily on"
#    },
#    {
#        "node_1": "limited direct mouse studies",
#        "node_2": "conflicting results",
#        "edge": "gave"
#    },
#    {
#        "node_1": "pathways regulated by growth factors in cardiomyocytes",
#        "node_2": "cardiac aging",
#        "edge": "discussed"
#    },
#    {
#        "node_1": "effects of IGF-1 on cardiac stem cell",
#        "node_2": "myocardial regeneration",
#        "edge": "related to"
#    },
#    {
#        "node_1": "adiposity of cardiac tissue",
#        "node_2": "role",
#        "edge": "touched on"
#    }
# ] [
#    {
#        "node_1": "on.North",
#        "node_2": "Sinclair",
#        "edge": "are mentioned in the same sentence"
#    }, {
#        "node_1": "Circ Res",
#        "node_2": "Author manuscript",
#        "edge": "are mentioned in the same sentence"
#    }, {
#        "node_1": "Available in PMC",
#        "node_2": "October 13",
#        "edge": "are mentioned in the same sentence"
#    }, {
#        "node_1": "NIH-PA Author Manuscript",
#        "node_2": "Author Manuscript",
#        "edge": "are mentioned in the same sentence"
#    }
# ] [
#    {
#        "node_1": "mitochondria",
#        "node_2": "cardiovascular aging",
#        "edge": "are related to each other"
#    }, {
#        "node_1": "cellular sources for energy generation",
#        "node_2": "mitochondria",
#        "edge": "are critically important for"
#    }, {
#        "node_1": "high energy–demanding tissues",
#        "node_2": "heart",
#        "edge": "such as the"
#    }, {
#        "node_1": "production of ROS",
#        "node_2": "mitochondria",
#        "edge": "are central to the rate of aging of these tissues"
#    }
# ] [
#    {
#        "node_1": "murine models",
#        "node_2": "reduced mitochondria ROS",
#        "edge": "reduce"
#    },
#    {
#        "node_1": "age-associated changes",
#        "node_2": "heart",
#        "edge": "in"
#    },
#    {
#        "node_1": "review",
#        "node_2": "role and molecular mechanisms regulating oxidative stress",
#        "edge": "discusses the"
#    },
#    {
#        "node_1": "oxidative stress",
#        "node_2": "aging cardiovascular system",
#        "edge": "in"
#    },
#    {
#        "node_1": "role of retrograde mitochondrial signaling",
#        "node_2": "communication from the mitochondria to the nucleus",
#        "edge": "discusses the role of"
#    },
#    {
#        "node_1": "mitochondrial biogenesis",
#        "node_2": "cardiovascular health",
#        "edge": "in"
#    }
# ] [
#    {
#        "node_1": "cellular aging",
#        "node_2": "telomere attrition",
#        "edge": "cause and effect"
#    },
#    {
#        "node_1": "telomere attrition",
#        "node_2": "mitochondria in the aging heart",
#        "edge": "related concepts"
#    },
#    {
#        "node_1": "cellular senescence",
#        "node_2": "Loss of telomeric DNA",
#        "edge": "cause and effect"
#    }
# ] [
#    {
#        "node_1": "attrition",
#        "node_2": "degeneration of stem and progenitor cell compartments",
#        "edge": "cause"
#    }, {
#        "node_1": "loss of telomeres",
#        "node_2": "highly dividing tissues",
#        "edge": "affects"
#    }, {
#        "node_1": "studies",
#        "node_2": "telomeric DNA loss effects in quiescent tissues",
#        "edge": "discussed"
#    }, {
#        "node_1": "role of telomere attrition",
#        "node_2": "augmenting age-related cardiac decline",
#        "edge": "discusses"
#    }, {
#        "node_1": "p53/mitochondrial signaling pathway",
#        "node_2": "characterize signaling pathways activated in response to loss of telomeric DNA",
#        "edge": "involved in"
#    }
# ] [
#    {
#        "node_1": "mitochondrial signaling pathway",
#        "node_2": "FOXOs/sirtuins",
#        "edge": "role of FOXOs/sirtuins in vascular aging"
#    },
#    {
#        "node_1": "FOXOs",
#        "node_2": "IGF-1 signaling",
#        "edge": "downstream effectors"
#    },
#    {
#        "node_1": "sirtuins",
#        "node_2": "lifespan and age-related diseases",
#        "edge": "association"
#    },
#    {
#        "node_1": "vascular development",
#        "node_2": "aging",
#        "edge": "both FOXO factors and sirtuins have been associated with"
#    }
# ] [
#    {
#        "node_1": "FOXO/sirtuin factors",
#        "node_2": "downstream effector pathway",
#        "edge": "are discussed, with particular emphasis"
#    }, {
#        "node_1": "vascular flow",
#        "node_2": "hypoxic responses",
#        "edge": "leading to modulators of these factors."
#    }, {
#        "node_1": "angiogenesis impairment",
#        "node_2": "endothelial dysfunction",
#        "edge": "in cardiovascular aging"
#    }, {
#        "node_1": "age-related impairment of angiogenesis",
#        "node_2": "end-organ damage seen in the elderly",
#        "edge": "contributes to increased"
#    }, {
#        "node_1": "angiogenesis impairment",
#        "node_2": "endothelial dysfunction",
#        "edge": "directly"
#    }
# ] [
#    {
#        "node_1": "cardiovascular health",
#        "node_2": "systemic tissue homeostasis",
#        "edge": "links"
#    },
#    {
#        "node_1": "angiogenesis",
#        "node_2": "elderly",
#        "edge": "critical in"
#    },
#    {
#        "node_1": "angiogenesis",
#        "node_2": "ischemic stroke",
#        "edge": "mechanism for repairing tissues after damage caused by"
#    },
#    {
#        "node_1": "angiogenesis",
#        "node_2": "myocardial infarction",
#        "edge": "mechanism for repairing tissues after damage caused by"
#    },
#    {
#        "node_1": "angiogenesis",
#        "node_2": "ischemia",
#        "edge": "mechanism for repairing tissues after damage caused by"
#    },
#    {
#        "node_1": "angiogenesis",
#        "node_2": "lower-limb ischemia",
#        "edge": "mechanism for repairing tissues after damage caused by"
#    },
#    {
#        "node_1": "processes and pathways",
#        "node_2": "impairment of angiogenesis",
#        "edge": "contributing to"
#    },
#    {
#        "node_1": "cellular senescence",
#        "node_2": "impairment of angiogenesis",
#        "edge": "including"
#    },
#    {
#        "node_1": "telomere attrition",
#        "node_2": "impairment of angiogenesis",
#        "edge": "including"
#    },
#    {
#        "node_1": "oxidative damage",
#        "node_2": "impairment of angiogenesis",
#        "edge": "including"
#    },
#    {
#        "node_1": "NO",
#        "node_2": "impairment of angiogenesis",
#        "edge": "including"
#    },
#    {
#        "node_1": "hypoxia",
#        "node_2": "impairment of angiogenesis",
#        "edge": "including"
#    },
#    {
#        "node_1": "vascular growth factors",
#        "node_2": "impairment of angiogenesis",
#        "edge": "including"
#    }
# ] [
#    {
#        "node_1": "angiogenesis",
#        "node_2": "therapeutic approaches",
#        "edge": "to improve angiogenesis"
#    },
#    {
#        "node_1": "cardiovascular aging",
#        "node_2": "nonmammalian models",
#        "edge": "discussed in the final part of the series"
#    },
#    {
#        "node_1": "zebrafish",
#        "node_2": "rudimentary heart and circulatory systems",
#        "edge": "observed in zebrafish"
#    },
#    {
#        "node_1": "Drosophila",
#        "node_2": "rudimentary heart and circulatory systems",
#        "edge": "observed in Drosophila"
#    },
#    {
#        "node_1": "genetics",
#        "node_2": "powerful use",
#        "edge": "in these systems has, and will continue"
#    }
# ] [
#    {
#        "node_1": "novel pathways",
#        "node_2": "cardiovascular biology",
#        "edge": "for discovering"
#    }, {
#        "node_1": "zebrafish",
#        "node_2": "aging research",
#        "edge": "not used for"
#    }, {
#        "node_1": "Drosophila",
#        "node_2": "discovery and confirmation of various aging pathways",
#        "edge": "used in discovery and confirmation"
#    }, {
#        "node_1": "nonmammalian models",
#        "node_2": "longevity",
#        "edge": "in terms of"
#    }, {
#        "node_1": "nonmammalian models",
#        "node_2": "cardiovascular aging",
#        "edge": "both in terms of"
#    }, {
#        "node_1": "history and discoveries",
#        "node_2": "various nonmammalian models",
#        "edge": "made in"
#    }
# ] [
#     {
#         "node_1": "NIH-PA Author Manuscript",
#         "node_2": "Author",
#         "edge": "is a document written by"
#     }
# ]

# %%
dfg1 = pd.read_csv(os.path.join(outputdirectory, "graph.csv"), sep="|")
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
print(dfg1.shape)
print(dfg1.head())

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape

# %%
import networkx as nx
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

net.show(graph_output_directory, notebook=False)
